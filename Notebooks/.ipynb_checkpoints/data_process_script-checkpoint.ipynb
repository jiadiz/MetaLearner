# %%
import pandas as pd
import os
print(os.getcwd())

import sys
from pathlib import Path

project_root = Path.cwd().parent.parent
sys.path.insert(0, str(project_root))
# Out:
# C:\Users\zhan5\OneDrive\Desktop\Quant\MetaLearner\Notebooks

# %%
from MetaLearner.Data.early_processing import (
    filter_for_date,
    drop_columns_with_na,
    create_column_of_days_after_2024,
    create_week_number_column,
)

# %%
from MetaLearner.Data.create_price_series import create_price_series_csv

price_data = create_price_series_csv()

price_data = filter_for_date(price_data)
price_data = drop_columns_with_na(price_data)
price_data = create_column_of_days_after_2024(price_data)
price_data = create_week_number_column(price_data )
price_data.shape
# Out:
# Downloading data for MMM...
# Downloading data for AOS...
# Downloading data for ABT...
# Downloading data for ABBV...
# Downloading data for ACN...
# Downloading data for ADBE...
# Downloading data for AMD...
# Downloading data for AES...
# Downloading data for AFL...
# Downloading data for A...
# Downloading data for APD...
# Downloading data for ABNB...
# Downloading data for AKAM...
# Downloading data for ALB...
# Downloading data for ARE...
# Downloading data for ALGN...
# Downloading data for ALLE...
# Downloading data for LNT...
# Downloading data for ALL...
# Downloading data for GOOGL...
# Downloading data for GOOG...
# Downloading data for MO...
# Downloading data for AMZN...
# Downloading data for AMCR...
# Downloading data for AMTM...
# Downloading data for AEE...
# Downloading data for AEP...
# Downloading data for AXP...
# Downloading data for AIG...
# Downloading data for AMT...
# Downloading data for AWK...
# Downloading data for AMP...
# Downloading data for AME...
# Downloading data for AMGN...
# Downloading data for APH...
# Downloading data for ADI...
# Downloading data for ANSS...
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: ANSS"}}}
# $ANSS: possibly delisted; no timezone found
#
# 1 Failed download:
# ['ANSS']: possibly delisted; no timezone found
#   Could not download data for ANSS
# Downloading data for AON...
# Downloading data for APA...
# Downloading data for AAPL...
# Downloading data for AMAT...
# Downloading data for APTV...
# Downloading data for ACGL...
# Downloading data for ADM...
# Downloading data for ANET...
# Downloading data for AJG...
# Downloading data for AIZ...
# Downloading data for T...
# Downloading data for ATO...
# Downloading data for ADSK...
# Downloading data for ADP...
# Downloading data for AZO...
# Downloading data for AVB...
# Downloading data for AVY...
# Downloading data for AXON...
# Downloading data for BKR...
# Downloading data for BALL...
# Downloading data for BAC...
# Downloading data for BAX...
# Downloading data for BDX...
# Downloading data for BRK.B...
# $BRK.B: possibly delisted; no timezone found
#
# 1 Failed download:
# ['BRK.B']: possibly delisted; no timezone found
#   Could not download data for BRK.B
# Downloading data for BBY...
# Downloading data for TECH...
# Downloading data for BIIB...
# Downloading data for BLK...
# Downloading data for BX...
# Downloading data for BK...
# Downloading data for BA...
# Downloading data for BKNG...
# Downloading data for BWA...
# Downloading data for BSX...
# Downloading data for BMY...
# Downloading data for AVGO...
# Downloading data for BR...
# Downloading data for BRO...
# Downloading data for BF.B...
# $BF.B: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-05-10)
#
# 1 Failed download:
# ['BF.B']: possibly delisted; no price data found  (1d 2018-01-01 -> 2026
py:184: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_data = train_data.reset_index()
# Saved 2099 rows to C:\Users\zhan5\OneDrive\Desktop\Quant\MetaLearner\Datafiles\all_daily_adjusted_close.csv
# Dropped columns ['ABNB_Close', 'AMTM_Close', 'CARR_Close', 'CEG_Close', 'CTRA_Close', 'GEHC_Close', 'GEV_Close', 'HOLX_Close', 'KVUE_Close', 'OTIS_Close', 'PLTR_Close', 'SOLV_Close', 'VLTO_Close', 'ACI_Close', 'AHR_Close', 'ALGM_Close', 'APG_Close', 'BROS_Close', 'BSY_Close', 'CART_Close', 'CAVA_Close', 'CNM_Close', 'CNXC_Close', 'CR_Close', 'CRBG_Close', 'DOCS_Close', 'DTM_Close', 'DUOL_Close', 'ESAB_Close', 'FOUR_Close', 'GTM_Close', 'GXO_Close', 'KD_Close', 'KNF_Close', 'MP_Close', 'NXT_Close', 'PATH_Close', 'ROIV_Close', 'RYAN_Close', 'SARO_Close', 'SHC_Close', 'TLN_Close', 'ULS_Close', 'VAL_Close', 'VNT_Close', 'WFRD_Close', 'WMG_Close']
# Their missing values are, CTRA_Close       1
# HOLX_Close      23
# CARR_Close      53
# OTIS_Close      53
# APG_Close       81
# WMG_Close      105
# GTM_Close      106
# FOUR_Close     107
# MP_Close       118
# ACI_Close      122
# BSY_Close      183
# VNT_Close      184
# PLTR_Close     188
# ALGM_Close     209
# SHC_Close      225
# CNXC_Close     227
# ROIV_Close     236
# ABNB_Close     238
# WFRD_Close     253
# PATH_Close     327
# VAL_Close      335
# DOCS_Close     372
# DTM_Close      377
# RYAN_Close     391
# GXO_Close      391
# CNM_Close      391
# DUOL_Close     395
# BROS_Close     429
# KD_Close       456
# CEG_Close      516
# ESAB_Close     564
# CRBG_Close     682
# GEHC_Close     745
# NXT_Close      782
# CR_Close       815
# KVUE_Close     840
# TLN_Close      860
# KNF_Close      862
# CAVA_Close     869
# CART_Close     934
# VLTO_Close     945
# AHR_Close     1031
# SOLV_Close    1064
# GEV_Close     1065
# ULS_Close     1076
# AMTM_Close    1189
# SARO_Close    1195
# dtype: int64
# C:\Users\zhan5\OneDrive\Desktop\Quant\MetaLearner\Data\early_processing.py:47: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   price_data['days'] = days_after_2024
# C:\Users\zhan5\OneDrive\Desktop\Quant\MetaLearner\Data\early_processing.py:67: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   price_data ['week'] = price_data ['Date'].apply(get_week_number)
# (1596, 1711)

# %%
from MetaLearner.Data.create_regime_data import (
    get_gold_n_intest_data,
    get_cpi_data,
    get_VIX_data,
    pull_sp500_data,
    create_regime_data
)

# %%
gold_n_treasury_prices  = get_gold_n_intest_data()
cpi_df, interest_rate_df = get_cpi_data()
vix = get_VIX_data()
sp500_df = pull_sp500_data()
# Out:
# [*********************100%***********************]  2 of 2 completed
# Price             Close                High                 Low         \
# Ticker             GC=F   ^TNX         GC=F   ^TNX         GC=F   ^TNX
# Date
# 2008-01-02   857.000000  3.901   857.799988  4.052   846.400024  3.892
# 2008-01-03   866.400024  3.901   865.500000  3.958   856.299988  3.892
# 2008-01-04   863.099976  3.854   865.500000  3.990   860.200012  3.809
# 2008-01-07   859.599976  3.839   860.900024  3.903   857.400024  3.833
# 2008-01-08   878.000000  3.840   879.400024  3.897   861.599976  3.837
# ...                 ...    ...          ...    ...          ...    ...
# 2026-05-04  4519.500000  4.446  4581.200195  4.464  4512.700195  4.390
# 2026-05-05  4555.799805  4.416  4580.500000  4.430  4547.600098  4.406
# 2026-05-06  4681.899902  4.356  4712.600098  4.372  4663.600098  4.348
# 2026-05-07  4699.799805  4.392  4736.200195  4.396  4699.799805  4.314
# 2026-05-08  4720.399902  4.364  4724.799805  4.388  4713.600098  4.346
#
# Price              Open        Volume
# Ticker             GC=F   ^TNX   GC=F ^TNX
# Date
# 2008-01-02   848.700012  4.033  130.0  0.0
# 2008-01-03   863.000000  3.892  181.0  0.0
# 2008-01-04   861.400024  3.914   28.0  0.0
# 2008-01-07   860.900024  3.893    4.0  0.0
# 2008-01-08   861.599976  3.873   21.0  0.0
# ...                 ...    ...    ...  ...
# 2026-05-04  4581.200195  4.400   20.0  0.0
# 2026-05-05  4547.600098  4.426  426.0  0.0
# 2026-05-06  4663.600098  4.366  212.0  0.0
# 2026-05-07  4704.799805  4.334  254.0  0.0
# 2026-05-08  4714.399902  4.372  254.0  0.0
#
# [4618 rows x 10 columns]
# 1947-01-01     21.480
# 1947-02-01     21.620
# 1947-03-01     22.000
# 1947-04-01     22.000
# 1947-05-01     21.950
#                ...
# 2025-11-01    325.063
# 2025-12-01    326.031
# 2026-01-01    326.588
# 2026-02-01    327.460
# 2026-03-01    330.293
# Length: 951, dtype: float64
# id                                                                    FEDFUNDS
# realtime_start                                                      2026-05-01
# realtime_end                                                        2026-05-01
# title                                             Federal Funds Effective Rate
# observation_start                                                   1954-07-01
# observation_end                                                     2026-04-01
# frequency                                                              Monthly
# frequency_short                                                              M
# units                                                                  Percent
# units_short                                                                  %
# seasonal_adjustment                                    Not Seasonally Adjusted
# seasonal_adjustment_short                                                  NSA
# last_updated                                            2026-05-01 15:20:39-05
# popularity                                                                  99
# notes                         Daily Federal Funds Rate from 1928-1954 (http...
# dtype: str
# 2025-11-01    325.063
# 2025-12-01    326.031
# 2026-01-01    326.588
# 2026-02-01    327.460
# 2026-03-01    330.293
# dtype: float64
# 2025-12-01    3.72
# 2026-01-01    3.64
# 2026-02-01    3.64
# 2026-03-01    3.64
# 2026-04-01    3.64
# dtype: float64
# [*********************100%***********************]  1 of 1 completed
# MultiIndex([( 'Date',     ''),
#             ('Close', '^VIX')],
#            names=['Price', 'Ticker'])
# [*********************100%***********************]  1 of 1 completed

# %%
# MetaLearner.Data.create_regime_data
regime_data = create_regime_data(
        sp500_df,
    interest_rate_df,
    cpi_df,
    gold_n_treasury_prices ,
    vix,
)
# Out:
# Number of missing data points: Date                         0
# sp500_Close                  0
# sp500_Volume                 0
# prev_month_interest_rate     0
# prev_month_cpi              25
# gold_close                   3
# treasury_yield_close         1
# VIX_Close                    0
# dtype: int64
# Forward filled

# %%
from MetaLearner.Data.examine_data_quality import download_daily_data, find_tickers,  check_data_quality

# %%
existing_tickers = find_tickers(price_data)
check_data_quality(price_data, existing_tickers)
# Out:
# Downloading data for ORA...
# [*********************100%***********************]  1 of 1 completed
# Downloading data for GWW...
# [*********************100%***********************]  1 of 1 completed
# Downloading data for GOOG...
# [*********************100%***********************]  1 of 1 completed
# Downloading data for FRT...
# [*********************100%***********************]  1 of 1 completed
# Downloading data for INTU...
# [*********************100%***********************]  1 of 1 completed
# Downloading data for BIIB...
# [*********************100%***********************]  1 of 1 completed
# Downloading data for ELAN...
# [*********************100%***********************]  1 of 1 completed
# Downloading data for MET...
# [*********************100%***********************]  1 of 1 completed
# Downloading data for NDSN...
# [*********************100%***********************]  1 of 1 completed
# Downloading data for KBH...
# [*********************100%***********************]  1 of 1 completed
# Index(['Date', 'ORA_Close_tested'], dtype='str') Index(['Date', 'ORA_Close_testing'], dtype='str')
# 0.9999999999995377
# Index(['Date', 'GWW_Close_tested'], dtype='str') Index(['Date', 'GWW_Close_testing'], dtype='str')
# 0.9999999999999574
# Index(['Date', 'GOOG_Close_tested'], dtype='str') Index(['Date', 'GOOG_Close_testing'], dtype='str')
# 0.9999999999999701
# Index(['Date', 'FRT_Close_tested'], dtype='str') Index(['Date', 'FRT_Close_testing'], dtype='str')
# 0.9999999999994761
# Index(['Date', 'INTU_Close_tested'], dtype='str') Index(['Date', 'INTU_Close_testing'], dtype='str')
# 0.9999999999998056
# Index(['Date', 'BIIB_Close_tested'], dtype='str') Index(['Date', 'BIIB_Close_testing'], dtype='str')
# 1.0
# Index(['Date', 'ELAN_Close_tested'], dtype='str') Index(['Date', 'ELAN_Close_testing'], dtype='str')
# 1.0
# Index(['Date', 'MET_Close_tested'], dtype='str') Index(['Date', 'MET_Close_testing'], dtype='str')
# 0.9999999999998301
# Index(['Date', 'NDSN_Close_tested'], dtype='str') Index(['Date', 'NDSN_Close_testing'], dtype='str')
# 0.9999999999995254
# Index(['Date', 'KBH_Close_tested'], dtype='str') Index(['Date', 'KBH_Close_testing'], dtype='str')
# 0.9999999999998745
# Data is good

# %%
price_data = filter_for_date(price_data, '2020-01-01')

# %%
from MetaLearner.Data.create_sector_and_industries import extract_price_and_volume_columns_and_tickers,  fetch_sector_industry, create_ticker_sector_industry_df

# %%
price_columns, volume_columns, tickers = extract_price_and_volume_columns_and_tickers(price_data)

# %%
sector_industry_df = create_ticker_sector_industry_df(tickers, fetch_sector_industry)
# Out:
# MMM
# AOS
# ABT
# ABBV
# ACN
# ADBE
# AMD
# AES
# AFL
# A
# APD
# AKAM
# ALB
# ARE
# ALGN
# ALLE
# LNT
# ALL
# GOOGL
# GOOG
# MO
# AMZN
# AMCR
# AEE
# AEP
# AXP
# AIG
# AMT
# AWK
# AMP
# AME
# AMGN
# APH
# ADI
# AON
# APA
# AAPL
# AMAT
# APTV
# ACGL
# ADM
# ANET
# IRT
# ITT
# JAZZ
# JEF
# JHG
# JLL
# KBH
# KBR
# KEX
# KMPR
# KNSL
# KNX
# KRC
# KRG
# KTOS
# LAD
# LAMR
# LEA
# LECO
# LFUS
# LITE
# LIVN
# LNTH
# LOPE
# LPX
# LSCC
# LSTR
# M
# MANH
# MASI
# MAT
# MEDP
# MIDD
# MKSI
# MLI
# MMS
# MORN
# MSA
# MSM
# MTDR
# MTG
# MTN
# MTSI
# MTZ
# MUR
# MUSA
# MZTI
# NBIX
# NEU
# NFG
# NJR
# NLY
# NNN
# NOV
# NOVT
# NSA
# NTNX
# NVST
# NVT
# NWE
# NXST
# NYT
# OC
# OGE
# OGS
# OHI
# OKTA
# OLED
# OLLI
# OLN
# ONB
# ONTO
# OPCH
# ORA
# ORI
# OSK
# OVV
# OZK
# PAG
# PB
# PBF
# PCTY
# PEGA
# PEN
# PFGC
# PII
# PINS
# PK
# PLNT
# PNFP
# POR
# POST
# PPC
# PR
# PRI
# PSN
# PSTG
# PVH
# QLYS
# R
# RBA
# RBC
# REXR
# RGA
# RGEN
# RGLD
# RH
# RLI
# RMBS
# RNR
# RPM
# RRC
# RRX
# RS
# RYN
# SAIA
# SAIC
# SAM
# SATS
# SBRA
# SCI
# SEIC
# SF
# SFM
# SGI
# SIGI
# SLAB
# SLGN
# SLM
# SMG
# SNX
# SON
# SPXC
# SR
# SSB
# SSD
# ST
# STAG
# STRL
# STWD
# SWX
# SYNA
# TCBI
# TEX
# THC
# THG
# THO
# TKR
# TMHC
# TNL
# TOL
# TREX
# TRU
# TTC
# TTEK
# TTMI
# TWLO
# TXNM
# TXRH
# UBSI
# UFPI
# UGI
# UMBF
# UNM
# USFD
# UTHR
# VC
# VFC
# VLY
# VMI
# VNO
# VNOM
# VOYA
# VVV
# WAL
# WBS
# WCC
# WEX
# WH
# WHR
# WING
# WLK
# WMS
# WPC
# WSO
# WTFC
# WTRG
# WTS
# WWD
# XPO
# XRAY
# YETI
# ZION
# XLK
# XLF
# XLI
# XLV
# XLY
# XLP
# XLU
# XLRE
# XLC
# XLE
# XLB
# SPY
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: SP500"}}}
# sp500

# %%
mapping = sector_industry_df.copy()

# %%
import numpy as np
import pandas as pd
from scipy.stats import pearsonr

# %%
price_data = price_data.set_index('Date')

# %%
tickers
# Out:
# ['MMM',
#  'AOS',
#  'ABT',
#  'ABBV',
#  'ACN',
#  'ADBE',
#  'AMD',
#  'AES',
#  'AFL',
#  'A',
#  'APD',
#  'AKAM',
#  'ALB',
#  'ARE',
#  'ALGN',
#  'ALLE',
#  'LNT',
#  'ALL',
#  'GOOGL',
#  'GOOG',
#  'MO',
#  'AMZN',
#  'AMCR',
#  'AEE',
#  'AEP',
#  'AXP',
#  'AIG',
#  'AMT',
#  'AWK',
#  'AMP',
#  'AME',
#  'AMGN',
#  'APH',
#  'ADI',
#  'AON',
#  'APA',
#  'AAPL',
#  'AMAT',
#  'APTV',
#  'ACGL',
#  'ADM',
#  'ANET',
#  'AJG',
#  'AIZ',
#  'T',
#  'ATO',
#  'ADSK',
#  'ADP',
#  'AZO',
#  'AVB',
#  'AVY',
#  'AXON',
#  'BKR',
#  'BALL',
#  'BAC',
#  'BAX',
#  'BDX',
#  'BBY',
#  'TECH',
#  'BIIB',
#  'BLK',
#  'BX',
#  'BK',
#  'BA',
#  'BKNG',
#  'BWA',
#  'BSX',
#  'BMY',
#  'AVGO',
#  'BR',
#  'BRO',
#  'BLDR',
#  'BG',
#  'BXP',
#  'CHRW',
#  'CDNS',
#  'CZR',
#  'CPT',
#  'CPB',
#  'COF',
#  'CAH',
#  'KMX',
#  'CCL',
#  'CAT',
#  'CBOE',
#  'CBRE',
#  'CDW',
#  'CE',
#  'COR',
#  'CNC',
#  'CNP',
#  'CF',
#  'CRL',
#  'SCHW',
#  'CHTR',
#  'CVX',
#  'CMG',
#  'CB',
#  'CHD',
#  'CI',
#  'CINF',
#  'CTAS',
#  'CSCO',
#  'C',
#  'CFG',
#  'CLX',
#  'CME',
#  'CMS',
#  'KO',
#  'CTSH',
#  'CL',
#  'CMCSA',
#  'CAG',
#  'COP',
#  'ED',
#  'STZ',
#  'COO',
#  'CPRT',
#  'GLW',
#  'CPAY',
#  'CTVA',
#  'CSGP',
#  'COST',
#  'CRWD',
#  'CCI',
#  'CSX',
#  'CMI',
#  'CVS',
#  'DHR',
#  'DRI',
#  'DVA',
#  'DECK',
#  'DE',
#  'DELL',
#  'DAL',
#  'DVN',
#  'DXCM',
#  'FANG',
#  'DLR',
#  'DG',
#  'DLTR',
#  'D',
#  'DPZ',
#  'DOV',
#  'DOW',
#  'DHI',
#  'DTE',
#  'DUK',
#  'DD',
#  'EMN',
#  'ETN',
#  'EBAY',
#  'ECL',
#  'EIX',
#  'EW',
#  'EA',
#  'ELV',
#  'EMR',
#  'ENPH',
#  'ETR',
#  'EOG',
#  'EPAM',
#  'EQT',
#  'EFX',
#  'EQIX',
#  'EQR',
#  'ERIE',
#  'ESS',
#  'EL',
#  'EG',
#  'EVRG',
#  'ES',
#  'EXC',
#  'EXPE',
#  'EXPD',
#  'EXR',
#  'XOM',
#  'FFIV',
#  'FDS',
#  'FICO',
#  'FAST',
#  'FRT',
#  'FDX',
#  'FIS',
#  'FITB',
#  'FSLR',
#  'FE',
#  'FMC',
#  'F',
#  'FTNT',
#  'FTV',
#  'FOXA',
#  'FOX',
#  'BEN',
#  'FCX',
#  'GRMN',
#  'IT',
#  'GE',
#  'GEN',
#  'GNRC',
#  'GD',
#  'GIS',
#  'GM',
#  'GPC',
#  'GILD',
#  'GPN',
#  'GL',
#  'GDDY',
#  'GS',
#  'HAL',
#  'HIG',
#  'HAS',
#  'HCA',
#  'DOC',
#  'HSIC',
#  'HSY',
#  'HPE',
#  'HLT',
#  'HD',
#  'HON',
#  'HRL',
#  'HST',
#  'HWM',
#  'HPQ',
#  'HUBB',
#  'HUM',
#  'HBAN',
#  'HII',
#  'IBM',
#  'IEX',
#  'IDXX',
#  'ITW',
#  'INCY',
#  'IR',
#  'PODD',
#  'INTC',
#  'ICE',
#  'IFF',
#  'IP',
#  'INTU',
#  'ISRG',
#  'IVZ',
#  'INVH',
#  'IQV',
#  'IRM',
#  'JBHT',
#  'JBL',
#  'JKHY',
#  'J',
#  'JNJ',
#  'JCI',
#  'JPM',
#  'KDP',
#  'KEY',
#  'KEYS',
#  'KMB',
#  'KIM',
#  'KMI',
#  'KKR',
#  'KLAC',
#  'KHC',
#  'KR',
#  'LHX',
#  'LH',
#  'LRCX',
#  'LW',
#  'LVS',
#  'LDOS',
#  'LEN',
#  'LLY',
#  'LIN',
#  'LYV',
#  'LKQ',
#  'LMT',
#  'L',
#  'LOW',
#  'LULU',
#  'LYB',
#  'MTB',
#  'MPC',
#  'MKTX',
#  'MAR',
#  'MLM',
#  'MAS',
#  'MA',
#  'MTCH',
#  'MKC',
#  'MCD',
#  'MCK',
#  'MDT',
#  'MRK',
#  'META',
#  'MET',
#  'MTD',
#  'MGM',
#  'MCHP',
#  'MU',
#  'MSFT',
#  'MAA',
#  'MRNA',
#  'MHK',
#  'MOH',
#  'TAP',
#  'MDLZ',
#  'MPWR',
#  'MNST',
#  'MCO',
#  'MS',
#  'MOS',
#  'MSI',
#  'MSCI',
#  'NDAQ',
#  'NTAP',
#  'NFLX',
#  'NEM',
#  'NWSA',
#  'NWS',
#  'NEE',
#  'NKE',
#  'NI',
#  'NDSN',
#  'NSC',
#  'NTRS',
#  'NOC',
#  'NCLH',
#  'NRG',
#  'NUE',
#  'NVDA',
#  'NVR',
#  'NXPI',
#  'ORLY',
#  'OXY',
#  'ODFL',
#  'OMC',
#  'ON',
#  'OKE',
#  'ORCL',
#  'PCAR',
#  'PKG',
#  'PANW',
#  'PH',
#  'PAYX',
#  'PAYC',
#  'PYPL',
#  'PNR',
#  'PEP',
#  'PFE',
#  'PCG',
#  'PM',
#  'PSX',
#  'PNW',
#  'PNC',
#  'POOL',
#  'PPG',
#  'PPL',
#  'PFG',
#  'PG',
#  'PGR',
#  'PLD',
#  'PRU',
#  'PEG',
#  'PTC',
#  'PSA',
#  'PHM',
#  'QRVO',
#  'PWR',
#  'QCOM',
#  'DGX',
#  'RL',
#  'RJF',
#  'RTX',
#  'O',
#  'REG',
#  'REGN',
#  'RF',
#  'RSG',
#  'RMD',
#  'RVTY',
#  'ROK',
#  'ROL',
#  'ROP',
#  'ROST',
#  'RCL',
#  'SPGI',
#  'CRM',
#  'SBAC',
#  'SLB',
#  'STX',
#  'SRE',
#  'NOW',
#  'SHW',
#  'SPG',
#  'SWKS',
#  'SJM',
#  'SW',
#  'SNA',
#  'SO',
#  'LUV',
#  'SWK',
#  'SBUX',
#  'STT',
#  'STLD',
#  'STE',
#  'SYK',
#  'SMCI',
#  'SYF',
#  'SNPS',
#  'SYY',
#  'TMUS',
#  'TROW',
#  'TTWO',
#  'TPR',
#  'TRGP',
#  'TGT',
#  'TEL',
#  'TDY',
#  'TFX',
#  'TER',
#  'TSLA',
#  'TXN',
#  'TPL',
#  'TXT',
#  'TMO',
#  'TJX',
#  'TSCO',
#  'TT',
#  'TDG',
#  'TRV',
#  'TRMB',
#  'TFC',
#  'TYL',
#  'TSN',
#  'USB',
#  'UBER',
#  'UDR',
#  'ULTA',
#  'UNP',
#  'UAL',
#  'UPS',
#  'URI',
#  'UNH',
#  'UHS',
#  'VLO',
#  'VTR',
#  'VRSN',
#  'VRSK',
#  'VZ',
#  'VRTX',
#  'VTRS',
#  'VICI',
#  'V',
#  'VST',
#  'VMC',
#  'WRB',
#  'GWW',
#  'WAB',
#  'WMT',
#  'DIS',
#  'WBD',
#  'WM',
#  'WAT',
#  'WEC',
#  'WFC',
#  'WELL',
#  'WST',
#  'WDC',
#  'WY',
#  'WMB',
#  'WTW',
#  'WYNN',
#  'XEL',
#  'XYL',
#  'YUM',
#  'ZBRA',
#  'ZBH',
#  'ZTS',
#  'AA',
#  'AAL',
#  'AAON',
#  'ACM',
#  'ADC',
#  'AEIS',
#  'AFG',
#  'AGCO',
#  'AIT',
#  'ALK',
#  'ALLY',
#  'ALV',
#  'AM',
#  'AMG',
#  'AMH',
#  'AMKR',
#  'AN',
#  'ANF',
#  'APPF',
#  'AR',
#  'ARMK',
#  'ARW',
#  'ASB',
#  'ASGN',
#  'ASH',
#  'ATI',
#  'ATR',
#  'AVAV',
#  'AVNT',
#  'AVT',
#  'AVTR',
#  'AXTA',
#  'AYI',
#  'BAH',
#  'BBWI',
#  'BC',
#  'BCO',
#  'BDC',
#  'BHF',
#  'BILL',
#  'BIO',
#  'BJ',
#  'BKH',
#  'BLD',
#  'BLKB',
#  'BMRN',
#  'BRBR',
#  'BRKR',
#  'BRX',
#  'BURL',
#  'BWXT',
#  'BYD',
#  'CACI',
#  'CAR',
#  'CASY',
#  'CBSH',
#  'CBT',
#  'CCK',
#  'CDP',
#  'CELH',
#  'CFR',
#  'CG',
#  'CGNX',
#  'CHDN',
#  'CHE',
#  'CHH',
#  'CHRD',
#  'CHWY',
#  'CIEN',
#  'CLF',
#  'CLH',
#  'CMC',
#  'CNH',
#  'CNO',
#  'CNX',
#  'COHR',
#  'COKE',
#  'COLB',
#  'COLM',
#  'COTY',
#  'CPRI',
#  'CROX',
#  'CRS',
#  'CRUS',
#  'CSL',
#  'CUBE',
#  'CUZ',
#  'CVLT',
#  'CW',
#  'CXT',
#  'CYTK',
#  'DAR',
#  'DBX',
#  'DCI',
#  'DINO',
#  'DKS',
#  'DLB',
#  'DOCU',
#  'DT',
#  'DY',
#  'EEFT',
#  'EGP',
#  'EHC',
#  'ELAN',
#  'ELF',
#  'ELS',
#  'ENS',
#  'ENSG',
#  'ENTG',
#  'EPR',
#  'EQH',
#  'ESNT',
#  'EVR',
#  'EWBC',
#  'EXEL',
#  'EXLS',
#  'EXP',
#  'EXPO',
#  'FAF',
#  'FBIN',
#  'FCFS',
#  'FCN',
#  'FFIN',
#  'FHI',
#  'FHN',
#  'FIVE',
#  'FLEX',
#  'FLG',
#  'FLO',
#  'FLR',
#  'FLS',
#  'FN',
#  'FNB',
#  'FND',
#  'FNF',
#  'FR',
#  'FTI',
#  'G',
#  'GAP',
#  'GATX',
#  'GBCI',
#  'GEF',
#  'GGG',
#  'GHC',
#  'GLPI',
#  'GME',
#  'GMED',
#  'GNTX',
#  'GPK',
#  'GT',
#  'GTLS',
#  'GWRE',
#  'H',
#  'HAE',
#  'HALO',
#  'HGV',
#  'HIMS',
#  'HL',
#  'HLI',
#  'HLNE',
#  'HOG',
#  'HOMB',
#  'HQY',
#  'HR',
#  'HRB',
#  'HWC',
#  'HXL',
#  'IBOC',
#  'IDA',
#  'ILMN',
#  'INGR',
#  'IPGP',
#  'IRT',
#  'ITT',
#  'JAZZ',
#  'JEF',
#  'JHG',
#  'JLL',
#  'KBH',
#  'KBR',
#  'KEX',
#  'KMPR',
#  'KNSL',
#  'KNX',
#  'KRC',
#  'KRG',
#  'KTOS',
#  'LAD',
#  'LAMR',
#  'LEA',
#  'LECO',
#  'LFUS',
#  'LITE',
#  'LIVN',
#  'LNTH',
#  'LOPE',
#  'LPX',
#  'LSCC',
#  'LSTR',
#  'M',
#  'MANH',
#  'MASI',
#  'MAT',
#  'MEDP',
#  'MIDD',
#  'MKSI',
#  'MLI',
#  'MMS',
#  'MORN',
#  'MSA',
#  'MSM',
#  'MTDR',
#  'MTG',
#  'MTN',
#  'MTSI',
#  'MTZ',
#  'MUR',
#  'MUSA',
#  'MZTI',
#  'NBIX',
#  'NEU',
#  'NFG',
#  'NJR',
#  'NLY',
#  'NNN',
#  'NOV',
#  'NOVT',
#  'NSA',
#  'NTNX',
#  'NVST',
#  'NVT',
#  'NWE',
#  'NXST',
#  'NYT',
#  'OC',
#  'OGE',
#  'OGS',
#  'OHI',
#  'OKTA',
#  'OLED',
#  'OLLI',
#  'OLN',
#  'ONB',
#  'ONTO',
#  'OPCH',
#  'ORA',
#  'ORI',
#  'OSK',
#  'OVV',
#  'OZK',
#  'PAG',
#  'PB',
#  'PBF',
#  'PCTY',
#  'PEGA',
#  'PEN',
#  'PFGC',
#  'PII',
#  'PINS',
#  'PK',
#  'PLNT',
#  'PNFP',
#  'POR',
#  'POST',
#  'PPC',
#  'PR',
#  'PRI',
#  'PSN',
#  'PSTG',
#  'PVH',
#  'QLYS',
#  'R',
#  'RBA',
#  'RBC',
#  'REXR',
#  'RGA',
#  'RGEN',
#  'RGLD',
#  'RH',
#  'RLI',
#  'RMBS',
#  'RNR',
#  'RPM',
#  'RRC',
#  'RRX',
#  'RS',
#  'RYN',
#  'SAIA',
#  'SAIC',
#  'SAM',
#  'SATS',
#  'SBRA',
#  'SCI',
#  'SEIC',
#  'SF',
#  'SFM',
#  'SGI',
#  'SIGI',
#  'SLAB',
#  'SLGN',
#  'SLM',
#  'SMG',
#  'SNX',
#  'SON',
#  'SPXC',
#  'SR',
#  'SSB',
#  'SSD',
#  'ST',
#  'STAG',
#  'STRL',
#  'STWD',
#  'SWX',
#  'SYNA',
#  'TCBI',
#  'TEX',
#  'THC',
#  'THG',
#  'THO',
#  'TKR',
#  'TMHC',
#  'TNL',
#  'TOL',
#  'TREX',
#  'TRU',
#  'TTC',
#  'TTEK',
#  'TTMI',
#  'TWLO',
#  'TXNM',
#  'TXRH',
#  'UBSI',
#  'UFPI',
#  'UGI',
#  'UMBF',
#  'UNM',
#  'USFD',
#  'UTHR',
#  'VC',
#  'VFC',
#  'VLY',
#  'VMI',
#  'VNO',
#  'VNOM',
#  'VOYA',
#  'VVV',
#  'WAL',
#  'WBS',
#  'WCC',
#  'WEX',
#  'WH',
#  'WHR',
#  'WING',
#  'WLK',
#  'WMS',
#  'WPC',
#  'WSO',
#  'WTFC',
#  'WTRG',
#  'WTS',
#  'WWD',
#  'XPO',
#  'XRAY',
#  'YETI',
#  'ZION',
#  'XLK',
#  'XLF',
#  'XLI',
#  'XLV',
#  'XLY',
#  'XLP',
#  'XLU',
#  'XLRE',
#  'XLC',
#  'XLE',
#  'XLB',
#  'SPY',
#  'sp500']

# %%
price_series = price_data[ 'LW_Close']

# %%
from MetaLearner.Data.MomentumFeatures import create_lag_return, create_fut_return,  create_auto_correlation_forecast, fill_missing_correlation_coefficients, popolute_momentum_data, create_compressed_forecast_features

# %%
# fill_missing_correlation_coefficients(p, 'MMM', 30, 21)   
# available_AR_values_per_stock

# %%
from MetaLearner.Data.MeanReversionFeatures1 import create_residual_mean_reversion_features, fill_missing_mean_reversion_features, create_mean_reversion_variants,  concat_mean_reversion_dataframes, build_other_mean_reversion_features

# %%
from  MetaLearner.Data.BuildBasicFeatures import build_features, build_base_features_for_one_ticker, add_sector, append_features, create_ranking_df, create_rolling_1m_volume_data, append_volume_data

# %%
import gc
gc.collect()

available_mean_reversion_features_per_ticker = {}

# %%
sector_to_etf = {
    "Industrials": "XLI",
    "Healthcare": "XLV",
    "Technology": "XLK",
    "Utilities": "XLU",
    "Financial Services": "XLF",
    "Basic Materials": "XLB",
    "Real Estate": "XLRE",
    "Communication Services": "XLC",
    "Consumer Defensive": "XLP",
    "Consumer Cyclical": "XLY",
    "Energy": "XLE",
    np.nan: "SPY"   # fallback
}

# %%
from pathlib import Path
import sys

# Ensure project root is importable regardless current notebook cwd.
project_root = Path.cwd()
if project_root.name.lower() == "notebooks" and project_root.parent.name.lower() == "metalearner":
    project_root = project_root.parent.parent
elif project_root.name.lower() == "metalearner":
    project_root = project_root.parent

if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from MetaLearner.Data.SaveLoadDictionaryDB import (
    load_dictionary_database,
    save_dictionary_database,
)

default_directory = str(project_root / "MetaLearner" / "Datafiles")
base_mr_file_name = "mean_reversion_base_feature_database.pkl"
vannila_mr_file_name = "vannila_mean_reversion_feature_database.pkl"

print(f"PKL databases will be stored in: {default_directory}")
# Out:
# PKL databases will be stored in: C:\Users\zhan5\OneDrive\Desktop\Quant\MetaLearner\Datafiles

# %%
tickers
# Out:
# ['MMM',
#  'AOS',
#  'ABT',
#  'ABBV',
#  'ACN',
#  'ADBE',
#  'AMD',
#  'AES',
#  'AFL',
#  'A',
#  'APD',
#  'AKAM',
#  'ALB',
#  'ARE',
#  'ALGN',
#  'ALLE',
#  'LNT',
#  'ALL',
#  'GOOGL',
#  'GOOG',
#  'MO',
#  'AMZN',
#  'AMCR',
#  'AEE',
#  'AEP',
#  'AXP',
#  'AIG',
#  'AMT',
#  'AWK',
#  'AMP',
#  'AME',
#  'AMGN',
#  'APH',
#  'ADI',
#  'AON',
#  'APA',
#  'AAPL',
#  'AMAT',
#  'APTV',
#  'ACGL',
#  'ADM',
#  'ANET',
#  'AJG',
#  'AIZ',
#  'T',
#  'ATO',
#  'ADSK',
#  'ADP',
#  'AZO',
#  'AVB',
#  'AVY',
#  'AXON',
#  'BKR',
#  'BALL',
#  'BAC',
#  'BAX',
#  'BDX',
#  'BBY',
#  'TECH',
#  'BIIB',
#  'BLK',
#  'BX',
#  'BK',
#  'BA',
#  'BKNG',
#  'BWA',
#  'BSX',
#  'BMY',
#  'AVGO',
#  'BR',
#  'BRO',
#  'BLDR',
#  'BG',
#  'BXP',
#  'CHRW',
#  'CDNS',
#  'CZR',
#  'CPT',
#  'CPB',
#  'COF',
#  'CAH',
#  'KMX',
#  'CCL',
#  'CAT',
#  'CBOE',
#  'CBRE',
#  'CDW',
#  'CE',
#  'COR',
#  'CNC',
#  'CNP',
#  'CF',
#  'CRL',
#  'SCHW',
#  'CHTR',
#  'CVX',
#  'CMG',
#  'CB',
#  'CHD',
#  'CI',
#  'CINF',
#  'CTAS',
#  'CSCO',
#  'C',
#  'CFG',
#  'CLX',
#  'CME',
#  'CMS',
#  'KO',
#  'CTSH',
#  'CL',
#  'CMCSA',
#  'CAG',
#  'COP',
#  'ED',
#  'STZ',
#  'COO',
#  'CPRT',
#  'GLW',
#  'CPAY',
#  'CTVA',
#  'CSGP',
#  'COST',
#  'CRWD',
#  'CCI',
#  'CSX',
#  'CMI',
#  'CVS',
#  'DHR',
#  'DRI',
#  'DVA',
#  'DECK',
#  'DE',
#  'DELL',
#  'DAL',
#  'DVN',
#  'DXCM',
#  'FANG',
#  'DLR',
#  'DG',
#  'DLTR',
#  'D',
#  'DPZ',
#  'DOV',
#  'DOW',
#  'DHI',
#  'DTE',
#  'DUK',
#  'DD',
#  'EMN',
#  'ETN',
#  'EBAY',
#  'ECL',
#  'EIX',
#  'EW',
#  'EA',
#  'ELV',
#  'EMR',
#  'ENPH',
#  'ETR',
#  'EOG',
#  'EPAM',
#  'EQT',
#  'EFX',
#  'EQIX',
#  'EQR',
#  'ERIE',
#  'ESS',
#  'EL',
#  'EG',
#  'EVRG',
#  'ES',
#  'EXC',
#  'EXPE',
#  'EXPD',
#  'EXR',
#  'XOM',
#  'FFIV',
#  'FDS',
#  'FICO',
#  'FAST',
#  'FRT',
#  'FDX',
#  'FIS',
#  'FITB',
#  'FSLR',
#  'FE',
#  'FMC',
#  'F',
#  'FTNT',
#  'FTV',
#  'FOXA',
#  'FOX',
#  'BEN',
#  'FCX',
#  'GRMN',
#  'IT',
#  'GE',
#  'GEN',
#  'GNRC',
#  'GD',
#  'GIS',
#  'GM',
#  'GPC',
#  'GILD',
#  'GPN',
#  'GL',
#  'GDDY',
#  'GS',
#  'HAL',
#  'HIG',
#  'HAS',
#  'HCA',
#  'DOC',
#  'HSIC',
#  'HSY',
#  'HPE',
#  'HLT',
#  'HD',
#  'HON',
#  'HRL',
#  'HST',
#  'HWM',
#  'HPQ',
#  'HUBB',
#  'HUM',
#  'HBAN',
#  'HII',
#  'IBM',
#  'IEX',
#  'IDXX',
#  'ITW',
#  'INCY',
#  'IR',
#  'PODD',
#  'INTC',
#  'ICE',
#  'IFF',
#  'IP',
#  'INTU',
#  'ISRG',
#  'IVZ',
#  'INVH',
#  'IQV',
#  'IRM',
#  'JBHT',
#  'JBL',
#  'JKHY',
#  'J',
#  'JNJ',
#  'JCI',
#  'JPM',
#  'KDP',
#  'KEY',
#  'KEYS',
#  'KMB',
#  'KIM',
#  'KMI',
#  'KKR',
#  'KLAC',
#  'KHC',
#  'KR',
#  'LHX',
#  'LH',
#  'LRCX',
#  'LW',
#  'LVS',
#  'LDOS',
#  'LEN',
#  'LLY',
#  'LIN',
#  'LYV',
#  'LKQ',
#  'LMT',
#  'L',
#  'LOW',
#  'LULU',
#  'LYB',
#  'MTB',
#  'MPC',
#  'MKTX',
#  'MAR',
#  'MLM',
#  'MAS',
#  'MA',
#  'MTCH',
#  'MKC',
#  'MCD',
#  'MCK',
#  'MDT',
#  'MRK',
#  'META',
#  'MET',
#  'MTD',
#  'MGM',
#  'MCHP',
#  'MU',
#  'MSFT',
#  'MAA',
#  'MRNA',
#  'MHK',
#  'MOH',
#  'TAP',
#  'MDLZ',
#  'MPWR',
#  'MNST',
#  'MCO',
#  'MS',
#  'MOS',
#  'MSI',
#  'MSCI',
#  'NDAQ',
#  'NTAP',
#  'NFLX',
#  'NEM',
#  'NWSA',
#  'NWS',
#  'NEE',
#  'NKE',
#  'NI',
#  'NDSN',
#  'NSC',
#  'NTRS',
#  'NOC',
#  'NCLH',
#  'NRG',
#  'NUE',
#  'NVDA',
#  'NVR',
#  'NXPI',
#  'ORLY',
#  'OXY',
#  'ODFL',
#  'OMC',
#  'ON',
#  'OKE',
#  'ORCL',
#  'PCAR',
#  'PKG',
#  'PANW',
#  'PH',
#  'PAYX',
#  'PAYC',
#  'PYPL',
#  'PNR',
#  'PEP',
#  'PFE',
#  'PCG',
#  'PM',
#  'PSX',
#  'PNW',
#  'PNC',
#  'POOL',
#  'PPG',
#  'PPL',
#  'PFG',
#  'PG',
#  'PGR',
#  'PLD',
#  'PRU',
#  'PEG',
#  'PTC',
#  'PSA',
#  'PHM',
#  'QRVO',
#  'PWR',
#  'QCOM',
#  'DGX',
#  'RL',
#  'RJF',
#  'RTX',
#  'O',
#  'REG',
#  'REGN',
#  'RF',
#  'RSG',
#  'RMD',
#  'RVTY',
#  'ROK',
#  'ROL',
#  'ROP',
#  'ROST',
#  'RCL',
#  'SPGI',
#  'CRM',
#  'SBAC',
#  'SLB',
#  'STX',
#  'SRE',
#  'NOW',
#  'SHW',
#  'SPG',
#  'SWKS',
#  'SJM',
#  'SW',
#  'SNA',
#  'SO',
#  'LUV',
#  'SWK',
#  'SBUX',
#  'STT',
#  'STLD',
#  'STE',
#  'SYK',
#  'SMCI',
#  'SYF',
#  'SNPS',
#  'SYY',
#  'TMUS',
#  'TROW',
#  'TTWO',
#  'TPR',
#  'TRGP',
#  'TGT',
#  'TEL',
#  'TDY',
#  'TFX',
#  'TER',
#  'TSLA',
#  'TXN',
#  'TPL',
#  'TXT',
#  'TMO',
#  'TJX',
#  'TSCO',
#  'TT',
#  'TDG',
#  'TRV',
#  'TRMB',
#  'TFC',
#  'TYL',
#  'TSN',
#  'USB',
#  'UBER',
#  'UDR',
#  'ULTA',
#  'UNP',
#  'UAL',
#  'UPS',
#  'URI',
#  'UNH',
#  'UHS',
#  'VLO',
#  'VTR',
#  'VRSN',
#  'VRSK',
#  'VZ',
#  'VRTX',
#  'VTRS',
#  'VICI',
#  'V',
#  'VST',
#  'VMC',
#  'WRB',
#  'GWW',
#  'WAB',
#  'WMT',
#  'DIS',
#  'WBD',
#  'WM',
#  'WAT',
#  'WEC',
#  'WFC',
#  'WELL',
#  'WST',
#  'WDC',
#  'WY',
#  'WMB',
#  'WTW',
#  'WYNN',
#  'XEL',
#  'XYL',
#  'YUM',
#  'ZBRA',
#  'ZBH',
#  'ZTS',
#  'AA',
#  'AAL',
#  'AAON',
#  'ACM',
#  'ADC',
#  'AEIS',
#  'AFG',
#  'AGCO',
#  'AIT',
#  'ALK',
#  'ALLY',
#  'ALV',
#  'AM',
#  'AMG',
#  'AMH',
#  'AMKR',
#  'AN',
#  'ANF',
#  'APPF',
#  'AR',
#  'ARMK',
#  'ARW',
#  'ASB',
#  'ASGN',
#  'ASH',
#  'ATI',
#  'ATR',
#  'AVAV',
#  'AVNT',
#  'AVT',
#  'AVTR',
#  'AXTA',
#  'AYI',
#  'BAH',
#  'BBWI',
#  'BC',
#  'BCO',
#  'BDC',
#  'BHF',
#  'BILL',
#  'BIO',
#  'BJ',
#  'BKH',
#  'BLD',
#  'BLKB',
#  'BMRN',
#  'BRBR',
#  'BRKR',
#  'BRX',
#  'BURL',
#  'BWXT',
#  'BYD',
#  'CACI',
#  'CAR',
#  'CASY',
#  'CBSH',
#  'CBT',
#  'CCK',
#  'CDP',
#  'CELH',
#  'CFR',
#  'CG',
#  'CGNX',
#  'CHDN',
#  'CHE',
#  'CHH',
#  'CHRD',
#  'CHWY',
#  'CIEN',
#  'CLF',
#  'CLH',
#  'CMC',
#  'CNH',
#  'CNO',
#  'CNX',
#  'COHR',
#  'COKE',
#  'COLB',
#  'COLM',
#  'COTY',
#  'CPRI',
#  'CROX',
#  'CRS',
#  'CRUS',
#  'CSL',
#  'CUBE',
#  'CUZ',
#  'CVLT',
#  'CW',
#  'CXT',
#  'CYTK',
#  'DAR',
#  'DBX',
#  'DCI',
#  'DINO',
#  'DKS',
#  'DLB',
#  'DOCU',
#  'DT',
#  'DY',
#  'EEFT',
#  'EGP',
#  'EHC',
#  'ELAN',
#  'ELF',
#  'ELS',
#  'ENS',
#  'ENSG',
#  'ENTG',
#  'EPR',
#  'EQH',
#  'ESNT',
#  'EVR',
#  'EWBC',
#  'EXEL',
#  'EXLS',
#  'EXP',
#  'EXPO',
#  'FAF',
#  'FBIN',
#  'FCFS',
#  'FCN',
#  'FFIN',
#  'FHI',
#  'FHN',
#  'FIVE',
#  'FLEX',
#  'FLG',
#  'FLO',
#  'FLR',
#  'FLS',
#  'FN',
#  'FNB',
#  'FND',
#  'FNF',
#  'FR',
#  'FTI',
#  'G',
#  'GAP',
#  'GATX',
#  'GBCI',
#  'GEF',
#  'GGG',
#  'GHC',
#  'GLPI',
#  'GME',
#  'GMED',
#  'GNTX',
#  'GPK',
#  'GT',
#  'GTLS',
#  'GWRE',
#  'H',
#  'HAE',
#  'HALO',
#  'HGV',
#  'HIMS',
#  'HL',
#  'HLI',
#  'HLNE',
#  'HOG',
#  'HOMB',
#  'HQY',
#  'HR',
#  'HRB',
#  'HWC',
#  'HXL',
#  'IBOC',
#  'IDA',
#  'ILMN',
#  'INGR',
#  'IPGP',
#  'IRT',
#  'ITT',
#  'JAZZ',
#  'JEF',
#  'JHG',
#  'JLL',
#  'KBH',
#  'KBR',
#  'KEX',
#  'KMPR',
#  'KNSL',
#  'KNX',
#  'KRC',
#  'KRG',
#  'KTOS',
#  'LAD',
#  'LAMR',
#  'LEA',
#  'LECO',
#  'LFUS',
#  'LITE',
#  'LIVN',
#  'LNTH',
#  'LOPE',
#  'LPX',
#  'LSCC',
#  'LSTR',
#  'M',
#  'MANH',
#  'MASI',
#  'MAT',
#  'MEDP',
#  'MIDD',
#  'MKSI',
#  'MLI',
#  'MMS',
#  'MORN',
#  'MSA',
#  'MSM',
#  'MTDR',
#  'MTG',
#  'MTN',
#  'MTSI',
#  'MTZ',
#  'MUR',
#  'MUSA',
#  'MZTI',
#  'NBIX',
#  'NEU',
#  'NFG',
#  'NJR',
#  'NLY',
#  'NNN',
#  'NOV',
#  'NOVT',
#  'NSA',
#  'NTNX',
#  'NVST',
#  'NVT',
#  'NWE',
#  'NXST',
#  'NYT',
#  'OC',
#  'OGE',
#  'OGS',
#  'OHI',
#  'OKTA',
#  'OLED',
#  'OLLI',
#  'OLN',
#  'ONB',
#  'ONTO',
#  'OPCH',
#  'ORA',
#  'ORI',
#  'OSK',
#  'OVV',
#  'OZK',
#  'PAG',
#  'PB',
#  'PBF',
#  'PCTY',
#  'PEGA',
#  'PEN',
#  'PFGC',
#  'PII',
#  'PINS',
#  'PK',
#  'PLNT',
#  'PNFP',
#  'POR',
#  'POST',
#  'PPC',
#  'PR',
#  'PRI',
#  'PSN',
#  'PSTG',
#  'PVH',
#  'QLYS',
#  'R',
#  'RBA',
#  'RBC',
#  'REXR',
#  'RGA',
#  'RGEN',
#  'RGLD',
#  'RH',
#  'RLI',
#  'RMBS',
#  'RNR',
#  'RPM',
#  'RRC',
#  'RRX',
#  'RS',
#  'RYN',
#  'SAIA',
#  'SAIC',
#  'SAM',
#  'SATS',
#  'SBRA',
#  'SCI',
#  'SEIC',
#  'SF',
#  'SFM',
#  'SGI',
#  'SIGI',
#  'SLAB',
#  'SLGN',
#  'SLM',
#  'SMG',
#  'SNX',
#  'SON',
#  'SPXC',
#  'SR',
#  'SSB',
#  'SSD',
#  'ST',
#  'STAG',
#  'STRL',
#  'STWD',
#  'SWX',
#  'SYNA',
#  'TCBI',
#  'TEX',
#  'THC',
#  'THG',
#  'THO',
#  'TKR',
#  'TMHC',
#  'TNL',
#  'TOL',
#  'TREX',
#  'TRU',
#  'TTC',
#  'TTEK',
#  'TTMI',
#  'TWLO',
#  'TXNM',
#  'TXRH',
#  'UBSI',
#  'UFPI',
#  'UGI',
#  'UMBF',
#  'UNM',
#  'USFD',
#  'UTHR',
#  'VC',
#  'VFC',
#  'VLY',
#  'VMI',
#  'VNO',
#  'VNOM',
#  'VOYA',
#  'VVV',
#  'WAL',
#  'WBS',
#  'WCC',
#  'WEX',
#  'WH',
#  'WHR',
#  'WING',
#  'WLK',
#  'WMS',
#  'WPC',
#  'WSO',
#  'WTFC',
#  'WTRG',
#  'WTS',
#  'WWD',
#  'XPO',
#  'XRAY',
#  'YETI',
#  'ZION',
#  'XLK',
#  'XLF',
#  'XLI',
#  'XLV',
#  'XLY',
#  'XLP',
#  'XLU',
#  'XLRE',
#  'XLC',
#  'XLE',
#  'XLB',
#  'SPY',
#  'sp500']

# %%
len([     'DPZ',
 'DOV',
 'DOW',
 'DHI',
 'DTE',
 'DUK',
 'DD',
 'EMN',
 'ETN',
 'EBAY',
 'ECL',
 'EIX',
 'EW',
 'EA',])
# Out:
# 14

# %%
import time
windows = [126, 252, 504]
t0 = time.perf_counter()

available_mean_reversion_features_per_ticker = load_dictionary_database(default_directory, base_mr_file_name )
vannila_mean_reversion_features = load_dictionary_database(default_directory, vannila_mr_file_name)
print('DB imported')
print("load:", time.perf_counter() - t0, "s,", "tickers:", len(available_mean_reversion_features_per_ticker))
# available_mean_reversion_features_per_ticker = {}
# vannila_mean_reversion_features  = {}

temp_tickers = [
    # 'ACN',
#  'ADBE',
#  'AMD',
#  'AES',
     'DPZ',
 'DOV',
 'DOW',
 'DHI',
 'DTE',
 'DUK',
 'DD',
 'EMN',
 'ETN',
 'EBAY',
 'ECL',
 'EIX',
 'EW',
 'EA',
 # 'ELV',
 # 'EMR',
 # 'ENPH',
 # 'ETR',
 # 'EOG',
 # 'EPAM',
 # 'EQT',
 # 'EFX'
    
 #                'ALGN',
 # 'ALLE',
 # 'LNT',
 # 'ALL',
 # 'GOOGL'
    # 'CHRW',
 # 'EHC',
 # 'DHI',
 # 'LW',
 # 'FAST',
 # 'THG',
 # 'ATO',
 # 'TGT',
 # 'WCC',
 # 'AMG'
               ]


selected_tickers = tickers


# Per-ticker population worker. Each thread handles exactly one ticker, so all
# writes land under available_mean_reversion_features_per_ticker[ticker][...]
# and vannila_mean_reversion_features[ticker], which are disjoint across workers.
# CPython makes per-key dict mutations atomic under the GIL, so no lock is needed.
def _populate_mean_reversion_for_ticker(ticker):
    sector = sector_industry_df[sector_industry_df['Ticker'] == ticker]['Sector'].iloc[0]
    etf_name = sector_to_etf[sector]

    stock_column = f'{ticker}_Close'
    etf_column = f'{etf_name}_Close'
    sp500_column = 'sp500_Close'

    p = price_data[stock_column]
    etf_p = price_data[etf_column]
    sp500_p = price_data[sp500_column]

    vannila_mean_reversion_df = build_other_mean_reversion_features(p, etf_p, sp500_p)
    vannila_mean_reversion_features[ticker] = vannila_mean_reversion_df

    for window in windows:
        fill_missing_mean_reversion_features(available_mean_reversion_features_per_ticker,
                                             p, etf_p, sp500_p,
                                             ticker, 'price', window)
        fill_missing_mean_reversion_features(available_mean_reversion_features_per_ticker,
                                             p, etf_p, sp500_p,
                                             ticker, 'return', window)
    return ticker


# Threads (not processes) so we share the in-memory feature dict instead of
# copying / re-pickling it per worker. sklearn/numpy/pandas release the GIL on
# their hot loops, so we still get real parallelism on multicore.
import os
from concurrent.futures import ThreadPoolExecutor, as_completed

n_mr_workers = min(os.cpu_count() or 4, len(selected_tickers))
t_pop = time.perf_counter()
with ThreadPoolExecutor(max_workers=14) as executor:
    futures = {executor.submit(_populate_mean_reversion_for_ticker, t): t for t in selected_tickers}
    for fut in as_completed(futures):
        ticker = futures[fut]
        try:
            fut.result()
        except Exception as e:
            print(f"[parallel mr] {ticker} failed: {e!r}")
            raise
print(f"populated {len(selected_tickers)} tickers in {time.perf_counter() - t_pop:.2f}s "
      f"using {n_mr_workers} threads")

save_dictionary_database(available_mean_reversion_features_per_ticker, default_directory, base_mr_file_name)
save_dictionary_database(vannila_mean_reversion_features , default_directory, vannila_mr_file_name)

price_mean_reversion_variants_dataframes = {}
return_mean_reversion_variants_dataframes = {}

for ticker in selected_tickers:
    price_mean_reversion_variants_df = create_mean_reversion_variants(available_mean_reversion_features_per_ticker, 
                                                                      ticker, windows, is_price_series = True)
    return_mean_reversion_variants_df = create_mean_reversion_variants(available_mean_reversion_features_per_ticker, 
                                                                       ticker, windows, is_price_series = False)
    price_mean_reversion_variants_dataframes[ticker] = price_mean_reversion_variants_df
    return_mean_reversion_variants_dataframes[ticker] =  return_mean_reversion_variants_df

print('Mean reversion data computation completed',  time.perf_counter() - t0, "s,")
# Out:
# Database found: C:\Users\zhan5\OneDrive\Desktop\Quant\MetaLearner\Datafiles\mean_reversion_base_feature_database.pkl
# Database found: C:\Users\zhan5\OneDrive\Desktop\Quant\MetaLearner\Datafiles\vannila_mean_reversion_feature_database.pkl
# DB imported
# load: 2.710400800104253 s, tickers: 26
# ABT data created
# ABT mean_reversion_sector_price_d126 data created
# MMM data created
# MMM mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d126 data created
# AOS data created
# AOS mean_reversion_sector_price_d126 data created
# ABBV data created
# ABBV mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# APD data created
# APD mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d126 data created
# AFL data created
# AFL mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d126 data created
# A data created
# A mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d126 data created
# ALB data created
# ALB mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# AKAM data created
# AKAM mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# ARE data created
# ARE mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d504 data created
# MO data created
# MO mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# GOOG data created
# GOOG mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d504 data created
# AMZN data created
# AMZN mean_reversion_sector_price_d126 data created
# AMCR data created
# AMCR mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# ALB mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# ARE mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# AKAM mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# AFL mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# APD mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# ABT mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# AMZN mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# ABBV mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# AMCR mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# MMM mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# MO mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# A mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# GOOG mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# AOS mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d126 data created
# ALB mean_reversion_sector_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d126 data created
# ARE mean_reversion_sector_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d126 data created
# AMCR mean_reversion_sector_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d126 data created
# AMZN mean_reversion_sector_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d126 data created
# AKAM mean_reversion_sector_return_d126 data created
# APD mean_reversion_sector_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d126 data created
# AFL mean_reversion_sector_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d126 data created
# ABT mean_reversion_sector_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d126 data created
# ABBV mean_reversion_sector_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d126 data created
# AOS mean_reversion_sector_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d126 data created
# A mean_reversion_sector_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d126 data created
# MO mean_reversion_sector_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d126 data created
# MMM mean_reversion_sector_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d126 data created
# GOOG mean_reversion_sector_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d126 data created
# ALB mean_reversion_econ_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d126 data created
# ARE mean_reversion_econ_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d126 data created
# APD mean_reversion_econ_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d126 data created
# ABT mean_reversion_econ_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d126 data created
# AKAM mean_reversion_econ_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d126 data created
# AFL mean_reversion_econ_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d126 data created
# AMCR mean_reversion_econ_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d126 data created
# AMZN mean_reversion_econ_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d126 data created
# ABBV mean_reversion_econ_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d126 data created
# AOS mean_reversion_econ_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d126 data created
# A mean_reversion_econ_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d126 data created
# MO mean_reversion_econ_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d126 data created
# MMM mean_reversion_econ_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d126 data created
# GOOG mean_reversion_econ_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d126 data created
# ALB mean_reversion_sector_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d126 data created
# ARE mean_reversion_sector_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d126 data created
# APD mean_reversion_sector_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d126 data created
# AKAM mean_reversion_sector_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d126 data created
# AMCR mean_reversion_sector_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d126 data created
# ABT mean_reversion_sector_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d126 data created
# AFL mean_reversion_sector_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d126 data created
# ABBV mean_reversion_sector_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d126 data created
# AOS mean_reversion_sector_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d126 data created
# AMZN mean_reversion_sector_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d126 data created
# GOOG mean_reversion_sector_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d126 data created
# MO mean_reversion_sector_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d126 data created
# A mean_reversion_sector_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d126 data created
# MMM mean_reversion_sector_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# ABT mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# APD mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# ARE mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# ALB mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# AKAM mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# ABBV mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# AFL mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# GOOG mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# AMCR mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# AMZN mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# MO mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# AOS mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# A mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# MMM mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# ABT mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# ARE mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# APD mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# AFL mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# ALB mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# AKAM mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# GOOG mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# MMM mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# ABBV mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# AMCR mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# AMZN mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# MO mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# AOS mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# A mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# ABT mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# APD mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# AFL mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# GOOG mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# AKAM mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# MMM mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# ALB mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# ARE mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# ABBV mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# AMZN mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# AMCR mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# AOS mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# MO mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# A mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# ABT mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# AFL mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# APD mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# GOOG mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# MMM mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# AKAM mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# ALB mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# ABBV mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# AMZN mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# ARE mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# A mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# AMCR mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# AOS mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# MO mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# ABT mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# AFL mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# MMM mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# APD mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# GOOG mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# AKAM mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# ARE mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# AOS mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# A mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# AMCR mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# AMZN mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# ABBV mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# ALB mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# MO mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# ABT mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# AFL mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# MMM mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# APD mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# GOOG mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# A mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# AKAM mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# AMCR mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# AOS mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# AMZN mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# ARE mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# ALB mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# ABBV mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# MO mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d504 data created
# ABT mean_reversion_econ_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d504 data created
# AFL mean_reversion_econ_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d504 data created
# MMM mean_reversion_econ_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d504 data created
# APD mean_reversion_econ_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d504 data created
# A mean_reversion_econ_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d504 data created
# GOOG mean_reversion_econ_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d504 data created
# AKAM mean_reversion_econ_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d504 data created
# ARE mean_reversion_econ_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d504 data created
# AOS mean_reversion_econ_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d504 data created
# AMZN mean_reversion_econ_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d504 data created
# AMCR mean_reversion_econ_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d504 data created
# ALB mean_reversion_econ_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d504 data created
# ABBV mean_reversion_econ_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d504 data created
# MO mean_reversion_econ_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d504 data created
# AEE data created
# AEE mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d504 data created
# AEP data created
# AEP mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d504 data created
# AXP data created
# AXP mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d504 data created
# AIG data created
# AIG mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d504 data created
# AMT data created
# AMT mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d504 data created
# AWK data created
# AWK mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d504 data created
# AMP data created
# AMP mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d504 data created
# AME data created
# AME mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d504 data created
# AMGN data created
# AMGN mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d504 data created
# APH data created
# APH mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d504 data created
# ADI data created
# ADI mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d504 data created
# AON data created
# AON mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d504 data created
# APA data created
# APA mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d504 data created
# AAPL data created
# AAPL mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# AEE mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# AEP mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# AIG mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# AXP mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# AMT mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# AMP mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# AWK mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# AME mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# AMGN mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# APH mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# ADI mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# AON mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# APA mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# AAPL mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d126 data created
# AEE mean_reversion_sector_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d126 data created
# AEP mean_reversion_sector_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d126 data created
# AIG mean_reversion_sector_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d126 data created
# AXP mean_reversion_sector_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d126 data created
# AMT mean_reversion_sector_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d126 data created
# AMP mean_reversion_sector_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d126 data created
# AWK mean_reversion_sector_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d126 data created
# AME mean_reversion_sector_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d126 data created
# AMGN mean_reversion_sector_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d126 data created
# APH mean_reversion_sector_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d126 data created
# ADI mean_reversion_sector_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d126 data created
# AON mean_reversion_sector_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d126 data created
# APA mean_reversion_sector_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d126 data created
# AAPL mean_reversion_sector_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d126 data created
# AEE mean_reversion_econ_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d126 data created
# AEP mean_reversion_econ_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d126 data created
# AIG mean_reversion_econ_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d126 data created
# AXP mean_reversion_econ_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d126 data created
# AMT mean_reversion_econ_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d126 data created
# AMP mean_reversion_econ_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d126 data created
# AWK mean_reversion_econ_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d126 data created
# AME mean_reversion_econ_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d126 data created
# AMGN mean_reversion_econ_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d126 data created
# APH mean_reversion_econ_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d126 data created
# ADI mean_reversion_econ_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d126 data created
# AON mean_reversion_econ_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d126 data created
# APA mean_reversion_econ_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d126 data created
# AAPL mean_reversion_econ_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d126 data created
# AEE mean_reversion_sector_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d126 data created
# AEP mean_reversion_sector_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d126 data created
# AIG mean_reversion_sector_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d126 data created
# AXP mean_reversion_sector_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d126 data created
# AMP mean_reversion_sector_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d126 data created
# AMT mean_reversion_sector_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d126 data created
# AME mean_reversion_sector_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d126 data created
# AWK mean_reversion_sector_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d126 data created
# AMGN mean_reversion_sector_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d126 data created
# APH mean_reversion_sector_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d126 data created
# ADI mean_reversion_sector_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d126 data created
# AON mean_reversion_sector_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d126 data created
# APA mean_reversion_sector_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d126 data created
# AAPL mean_reversion_sector_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# AEE mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# AEP mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# AIG mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# AXP mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# AMP mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# AMT mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# AWK mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# AME mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# AMGN mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# APH mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# ADI mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# AON mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# APA mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# AAPL mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# AEE mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# AEP mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# AIG mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# AXP mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# AMP mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# AMT mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# AWK mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# AME mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# AMGN mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# ADI mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# APH mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# AON mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# AAPL mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# APA mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# AEE mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# AEP mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# AXP mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# AIG mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# AMP mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# AMT mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# AME mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# AWK mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# AMGN mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# ADI mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# APH mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# AON mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# AAPL mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# APA mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# AEE mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# AEP mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# AXP mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# AIG mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# AMT mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# AMP mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# AME mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# AWK mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# AMGN mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# ADI mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# AON mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# APH mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# AAPL mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# APA mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# AEE mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# AEP mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# AXP mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# AIG mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# AMP mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# AWK mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# AMT mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# AME mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# AMGN mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# ADI mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# AON mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# APH mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# APA mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# AAPL mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# AEE mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# AEP mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# AXP mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# AIG mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# AMP mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# AWK mean_reversion_sector_return_d504 data created
# ...
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d126 data created
# NWS mean_reversion_econ_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# MS mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d126 data created
# NWSA mean_reversion_sector_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d126 data created
# NEE mean_reversion_econ_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# MPWR mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# MOS mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d126 data created
# NWS mean_reversion_sector_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# MSI mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# MSCI mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# NDAQ mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# NTAP mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d126 data created
# NEE mean_reversion_sector_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# MNST mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# MCO mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# NFLX mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# NEM mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# MS mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# NWSA mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# MPWR mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# MOS mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# NWS mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# MSI mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# MSCI mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# NDAQ mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# NTAP mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d252 data created
# NEE mean_reversion_econ_price_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# MNST mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# MCO mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# NFLX mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# NEM mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# MS mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# NWSA mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# MPWR mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# MOS mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# MSI mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# NWS mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# MSCI mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# NDAQ mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# NTAP mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d252 data created
# NEE mean_reversion_sector_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# MNST mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# MCO mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# NFLX mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# NEM mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# MS mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# NWSA mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# MOS mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# MSI mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# NWS mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# MSCI mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# NDAQ mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# NTAP mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d252 data created
# NEE mean_reversion_econ_return_d252 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# MPWR mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# NFLX mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# NEM mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# MNST mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# MCO mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# NWSA mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# MS mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# NWS mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d252 data created
# NEE mean_reversion_sector_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# MOS mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# MSI mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# MSCI mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# NDAQ mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# NTAP mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# MPWR mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# NFLX mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# NEM mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# MNST mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# MCO mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# NWSA mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# MS mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# NWS mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d504 data created
# NEE mean_reversion_econ_price_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# MOS mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# MSI mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# MSCI mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# NDAQ mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# NTAP mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d504 data created
# MPWR mean_reversion_econ_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# NFLX mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# NEM mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d504 data created
# MNST mean_reversion_econ_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d504 data created
# MCO mean_reversion_econ_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# NWSA mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d504 data created
# MS mean_reversion_econ_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# NWS mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d504 data created
# NEE mean_reversion_sector_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d504 data created
# MOS mean_reversion_econ_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d504 data created
# MSI mean_reversion_econ_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d504 data created
# MSCI mean_reversion_econ_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d504 data created
# NDAQ mean_reversion_econ_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d504 data created
# NTAP mean_reversion_econ_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d504 data created
# NKE data created
# NKE mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d504 data created
# NFLX mean_reversion_econ_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d504 data created
# NEM mean_reversion_econ_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d504 data created
# NI data created
# NI mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d504 data created
# NWSA mean_reversion_econ_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d504 data created
# NDSN data created
# NDSN mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# NKE mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d504 data created
# NSC data created
# NSC mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d504 data created
# NWS mean_reversion_econ_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# NI mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# NDSN mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d126 data created
# NKE mean_reversion_sector_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d504 data created
# NTRS data created
# NTRS mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d504 data created
# NOC data created
# NOC mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d504 data created
# NEE mean_reversion_econ_return_d504 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d504 data created
# NCLH data created
# NCLH mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# NSC mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d504 data created
# NRG data created
# NRG mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d504 data created
# NUE data created
# NUE mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d126 data created
# NI mean_reversion_sector_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d126 data created
# NDSN mean_reversion_sector_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_return_d126 data created
# NKE mean_reversion_econ_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# NTRS mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d504 data created
# NVDA data created
# NVDA mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# NOC mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_return_d504 data created
# NVR data created
# NVR mean_reversion_sector_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# NCLH mean_reversion_econ_price_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_econ_price_d126 data created
# NSC mean_reversion_sector_return_d126 data created
# Data until  2026-05-08 00:00:00 mean_reversion_sector_price_d126 data created
# NRG mean_reversion_econ_price_d126 data created

# %%
# ((469/4)*950)/60/60
469/4, 590/5, 1711.85/14

# %%
price_mean_reversion_variants_dataframes = {}
return_mean_reversion_variants_dataframes = {}

for ticker in selected_tickers:
    print(ticker)
    price_mean_reversion_variants_df = create_mean_reversion_variants(available_mean_reversion_features_per_ticker, 
                                                                      ticker, windows, is_price_series = True)
    return_mean_reversion_variants_df = create_mean_reversion_variants(available_mean_reversion_features_per_ticker, 
                                                                       ticker, windows, is_price_series = False)
    price_mean_reversion_variants_dataframes[ticker] = price_mean_reversion_variants_df
    return_mean_reversion_variants_dataframes[ticker] =  return_mean_reversion_variants_df
# Out:
# EHC
# THG
# ATO

# %%
selected_tickers = temp_tickers 
# ['CHRW', 'EHC', 'DHI', 'LW', 'FAST', 'THG', 'ATO']

# %%
    
global_mean_reversion_df = concat_mean_reversion_dataframes([vannila_mean_reversion_features,
    price_mean_reversion_variants_dataframes,
    return_mean_reversion_variants_dataframes], selected_tickers).reset_index().rename(columns = {'index':'Date'})

# %%
            
LOOKBACKS = [1, 5, 10, 25, 60, 120, 250]

mom_file_name = "momentum_feature_database.pkl"

available_AR_values_per_stock = load_dictionary_database(default_directory, mom_file_name )
# available_AR_values_per_stock = {}


# Per-ticker momentum population worker. Each thread handles exactly one ticker,
# so all writes land under available_AR_values_per_stock[ticker][lag_fut_combo],
# which is disjoint across workers. CPython makes per-key dict mutations atomic
# under the GIL, so no lock is needed.
def _populate_momentum_for_ticker(ticker):
    popolute_momentum_data(price_data, available_AR_values_per_stock,
                           LOOKBACKS, [ticker])
    return ticker


import os
import time
from concurrent.futures import ThreadPoolExecutor, as_completed

n_mom_workers = min(os.cpu_count() or 4, len(selected_tickers))
t_mom = time.perf_counter()
with ThreadPoolExecutor(max_workers=n_mom_workers) as executor:
    futures = {executor.submit(_populate_momentum_for_ticker, t): t for t in selected_tickers}
    for fut in as_completed(futures):
        ticker = futures[fut]
        try:
            fut.result()
        except Exception as e:
            print(f"[parallel mom] {ticker} failed: {e!r}")
            raise
print(f"populated momentum for {len(selected_tickers)} tickers in "
      f"{time.perf_counter() - t_mom:.2f}s using {n_mom_workers} threads")

save_dictionary_database(available_AR_values_per_stock , default_directory, mom_file_name)
# Out:
# Database found: C:\Users\zhan5\OneDrive\Desktop\Quant\MetaLearner\Datafiles\momentum_feature_database.pkl
# EHC
# 1
# THG
# 1
# ATO
# 1
# 5
# 10
# 25
# 5
# 5
# 10
# 60
# 10
# 25
# 25
# 120
# 60
# 60
# 120
# 250
# 120
# 250
# 250
# populated momentum for 3 tickers in 0.15s using 3 threads
# 'C:\\Users\\zhan5\\OneDrive\\Desktop\\Quant\\MetaLearner\\Datafiles\\momentum_feature_database.pkl'

# %%
all_momentum_features = []

ticker_dfs = []

for ticker in selected_tickers:
    print(ticker)
    ticker_series = pd.DataFrame()
    ticker_data = available_AR_values_per_stock[ticker]
    for combo in ticker_data:
        print(combo)
        lag_time = combo.split('_')[1]
        return_and_p_value = pd.Series(ticker_data[combo])
        return_series = return_and_p_value.apply(lambda x: x[0])
        p_value_series = return_and_p_value.apply(lambda x: x[1])
        corr_coef = return_and_p_value.apply(lambda x: x[2])
        ret_lag = return_and_p_value.apply(lambda x: x[3])
        
        ticker_series[f'{combo}_forecast_return'] = return_series
        ticker_series[f'{combo}_p_value'] = p_value_series
        ticker_series[f'{combo}_corr_coef'] = corr_coef
        ticker_series[f'{combo}_ret_lag'] = ret_lag
        ticker_series[f'forecast_s_times_1_minus_pval_{lag_time}'] = return_series*(1-p_value_series)
        ticker_series['Ticker'] = ticker
        # ticker_dfs.append(ticker_series)
    # ticker_momentum_df = pd.concat(ticker_dfs, axis = 1).reset_index().rename(columns = {'index':'Date'})
    # print(ticker_momentum_df.shape)
    ticker_momentum_df = ticker_series
    all_momentum_features.append(ticker_momentum_df)
momentum_df = pd.concat(all_momentum_features).reset_index().rename(columns = {'index':'Date'})
# Out:
# EHC
# lag_1_hold_21
# lag_5_hold_21
# lag_10_hold_21
# lag_25_hold_21
# lag_60_hold_21
# lag_120_hold_21
# lag_250_hold_21
# THG
# lag_1_hold_21
# lag_5_hold_21
# lag_10_hold_21
# lag_25_hold_21
# lag_60_hold_21
# lag_120_hold_21
# lag_250_hold_21
# ATO
# lag_1_hold_21
# lag_5_hold_21
# lag_10_hold_21
# lag_25_hold_21
# lag_60_hold_21
# lag_120_hold_21
# lag_250_hold_21

# %%
vannila_mean_reversion_features.keys()
# Out:
# dict_keys(['EHC', 'THG', 'ATO'])

# %% [markdown]
# Creating a mean reversion dataframe for MMM to see if the features computed is identical with the features computed by

# %%
temp = pd.concat([vannila_mean_reversion_features['EHC'], price_mean_reversion_variants_dataframes['EHC'], return_mean_reversion_variants_dataframes['EHC']], axis = 1)

# %%
temp = global_mean_reversion_df[global_mean_reversion_df ['Ticker'] == 'EHC'].reset_index()
temp
# Out:
#       index       Date  Stock_price   ETF_price  SP500_price  Stock_return  \
# 0         0 2020-01-02    51.171631   92.306099  3257.850098           NaN
# 1         1 2020-01-03    51.179028   91.501709  3234.850098      0.000145
# 2         2 2020-01-06    50.994053   92.071106  3246.280029     -0.003621
# 3         3 2020-01-07    50.483517   91.890350  3237.179932     -0.010062
# 4         4 2020-01-08    50.979252   92.486847  3253.050049      0.009772
# ...     ...        ...          ...         ...          ...           ...
# 1591   1591 2026-05-04   106.639999  144.729996  7200.750000     -0.007846
# 1592   1592 2026-05-05   105.160004  145.300003  7259.220215     -0.013976
# 1593   1593 2026-05-06   105.010002  145.399994  7365.120117     -0.001427
# 1594   1594 2026-05-07   107.150002  144.720001  7337.109863      0.020174
# 1595   1595 2026-05-08   106.099998  143.490005  7398.930176     -0.009848
#
#       Sector_return  Econ_return     vr_5d    vr_20d  ...  \
# 0               NaN          NaN       NaN       NaN  ...
# 1         -0.008753    -0.007085       NaN       NaN  ...
# 2          0.006204     0.003527       NaN       NaN  ...
# 3         -0.001965    -0.002807       NaN       NaN  ...
# 4          0.006470     0.004890       NaN       NaN  ...
# ...             ...          ...       ...       ...  ...
# 1591      -0.002967    -0.004070  0.179190  0.117033  ...
# 1592       0.003931     0.008087  0.135538  0.098195  ...
# 1593       0.000688     0.014483  0.117657  0.112642  ...
# 1594      -0.004688    -0.003810  0.054270  0.125344  ...
# 1595      -0.008535     0.008390  1.095323  0.138919  ...
#
#       econ_r_resid_std_times_z_times_1_minus_p_value_504  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1591                                          -0.006089
# 1592                                          -0.018077
# 1593                                          -0.008570
# 1594                                           0.021877
# 1595                                          -0.014038
#
#       econ_r_res_mom_12_1_504  econ_r_res_rev_5d_504  econ_r_res_rsi_14_504  \
# 0                         NaN                    NaN                    NaN
# 1                         NaN                    NaN                    NaN
# 2                         NaN                    NaN                    NaN
# 3                         NaN                    NaN                    NaN
# 4                         NaN                    NaN                    NaN
# ...                       ...                    ...                    ...
# 1591                -0.296359              -0.052708              51.190585
# 1592                -0.225604              -0.024749              49.982039
# 1593                -0.242793              -0.007091              48.594482
# 1594                -0.233141              -0.059806              52.672844
# 1595                -0.209638               0.024897              48.264359
#
#       econ_r_res_streak_504  econ_r_macd_line_504  econ_r_macd_signal_504  \
# 0                       NaN                   NaN                     NaN
# 1                       NaN                   NaN                     NaN
# 2                       NaN                   NaN                     NaN
# 3                       NaN                   NaN                     NaN
# 4                       NaN                   NaN                     NaN
# ...                     ...                   ...                     ...
# 1591                    0.0              0.002730                0.000228
# 1592                    0.0              0.000776                0.000338
# 1593                    0.0             -0.000005                0.000269
# 1594                    1.0              0.001812                0.000578
# 1595                    0.0              0.000349                0.000532
#
#       econ_r_macd_hist_504  econ_r_resid_forecast_504  Ticker
# 0                      NaN                        NaN     EHC
# 1                      NaN                        NaN     EHC
# 2                      NaN                        NaN     EHC
# 3                      NaN                        NaN     EHC
# 4                      NaN                        NaN     EHC
# ...                    ...                        ...     ...
# Econ_return
# vr_5d
# vr_20d
# vr_60d
# vr_120d
# sector_tracking_error_d1
# econ_tracking_error_d1
# sector_p_beta_d126
# sector_p_resid_std_d126
# sector_p_resid_z_d126
# sector_p_resid_total_deviation_per_price_d126
# sector_p_resid_adf_p_d126
# sector_p_z_times_1_minus_p_value_126
# sector_p_resid_std_times_z_times_1_minus_p_value_126
# sector_p_res_mom_06_1_126
# sector_p_res_rev_5d_126
# sector_p_res_rsi_14_126
# sector_p_res_streak_126
# sector_p_macd_line_126
# sector_p_macd_signal_126
# sector_p_macd_hist_126
# sector_p_resid_forecast_126
# sector_p_beta_d252
# sector_p_resid_std_d252
# sector_p_resid_z_d252
# sector_p_resid_total_deviation_per_price_d252
# sector_p_resid_adf_p_d252
# sector_p_z_times_1_minus_p_value_252
# sector_p_resid_std_times_z_times_1_minus_p_value_252
# sector_p_res_mom_12_1_252
# sector_p_res_rev_5d_252
# sector_p_res_rsi_14_252
# sector_p_res_streak_252
# sector_p_macd_line_252
# sector_p_macd_signal_252
# sector_p_macd_hist_252
# sector_p_resid_forecast_252
# sector_p_beta_d504
# sector_p_resid_std_d504
# sector_p_resid_z_d504
# sector_p_resid_total_deviation_per_price_d504
# sector_p_resid_adf_p_d504
# sector_p_z_times_1_minus_p_value_504
# sector_p_resid_std_times_z_times_1_minus_p_value_504
# sector_p_res_mom_12_1_504
# sector_p_res_rev_5d_504
# sector_p_res_rsi_14_504
# sector_p_res_streak_504
# sector_p_macd_line_504
# sector_p_macd_signal_504
# sector_p_macd_hist_504
# sector_p_resid_forecast_504
# econ_p_beta_d126
# econ_p_resid_std_d126
# econ_p_resid_z_d126
# econ_p_resid_total_deviation_per_price_d126
# econ_p_resid_adf_p_d126
# econ_p_z_times_1_minus_p_value_126
# econ_p_resid_std_times_z_times_1_minus_p_value_126
# econ_p_res_mom_06_1_126
# econ_p_res_rev_5d_126
# econ_p_res_rsi_14_126
# econ_p_res_streak_126
# econ_p_macd_line_126
# econ_p_macd_signal_126
# econ_p_macd_hist_126
# econ_p_resid_forecast_126
# econ_p_beta_d252
# econ_p_resid_std_d252
# econ_p_resid_z_d252
# econ_p_resid_total_deviation_per_price_d252
# econ_p_resid_adf_p_d252
# econ_p_z_times_1_minus_p_value_252
# econ_p_resid_std_times_z_times_1_minus_p_value_252
# econ_p_res_mom_12_1_252
# econ_p_res_rev_5d_252
# econ_p_res_rsi_14_252
# econ_p_res_streak_252
# econ_p_macd_line_252
# econ_p_macd_signal_252
# econ_p_macd_hist_252
# econ_p_resid_forecast_252
# econ_p_beta_d504
# econ_p_resid_std_d504
# econ_p_resid_z_d504
# econ_p_resid_total_deviation_per_price_d504
# econ_p_resid_adf_p_d504
# econ_p_z_times_1_minus_p_value_504
# econ_p_resid_std_times_z_times_1_minus_p_value_504
# econ_p_res_mom_12_1_504
# econ_p_res_rev_5d_504
# econ_p_res_rsi_14_504
# econ_p_res_streak_504
# econ_p_macd_line_504
# econ_p_macd_signal_504
# econ_p_macd_hist_504
# econ_p_resid_forecast_504
# sector_r_beta_d126
# sector_r_resid_std_d126
# sector_r_resid_z_d126
# sector_r_resid_total_deviation_per_price_d126
# sector_r_resid_adf_p_d126
# sector_r_z_times_1_minus_p_value_126
# sector_r_resid_std_times_z_times_1_minus_p_value_126
# sector_r_res_mom_06_1_126
# sector_r_res_rev_5d_126
# sector_r_res_rsi_14_126
# sector_r_res_streak_126
# sector_r_macd_line_126
# sector_r_macd_signal_126
# sector_r_macd_hist_126
# sector_r_resid_forecast_126
# sector_r_beta_d252
# sector_r_resid_std_d252
# sector_r_resid_z_d252
# sector_r_resid_total_deviation_per_price_d252
# sector_r_resid_adf_p_d252
# sector_r_z_times_1_minus_p_value_252
# sector_r_resid_std_times_z_times_1_minus_p_value_252
# sector_r_res_mom_12_1_252
# sector_r_res_rev_5d_252
# sector_r_res_rsi_14_252
# sector_r_res_streak_252
# sector_r_macd_line_252
# sector_r_macd_signal_252
# sector_r_macd_hist_252
# sector_r_resid_forecast_252
# sector_r_beta_d504
# sector_r_resid_std_d504
# sector_r_resid_z_d504
# sector_r_resid_total_deviation_per_price_d504
# sector_r_resid_adf_p_d504
# sector_r_z_times_1_minus_p_value_504
# sector_r_resid_std_times_z_times_1_minus_p_value_504
# sector_r_res_mom_12_1_504
# sector_r_res_rev_5d_504
# sector_r_res_rsi_14_504
# sector_r_res_streak_504
# sector_r_macd_line_504
# sector_r_macd_signal_504
# sector_r_macd_hist_504
# sector_r_resid_forecast_504
# econ_r_beta_d126
# econ_r_resid_std_d126
# econ_r_resid_z_d126
# econ_r_resid_total_deviation_per_price_d126
# econ_r_resid_adf_p_d126
# econ_r_z_times_1_minus_p_value_126
# econ_r_resid_std_times_z_times_1_minus_p_value_126
# econ_r_res_mom_06_1_126
# econ_r_res_rev_5d_126
# econ_r_res_rsi_14_126
# econ_r_res_streak_126
# econ_r_macd_line_126
# econ_r_macd_signal_126
# econ_r_macd_hist_126
# econ_r_resid_forecast_126
# econ_r_beta_d252
# econ_r_resid_std_d252
# econ_r_resid_z_d252
# econ_r_resid_total_deviation_per_price_d252
# econ_r_resid_adf_p_d252
# econ_r_z_times_1_minus_p_value_252
# econ_r_resid_std_times_z_times_1_minus_p_value_252
# econ_r_res_mom_12_1_252
# econ_r_res_rev_5d_252
# econ_r_res_rsi_14_252
# econ_r_res_streak_252
# econ_r_macd_line_252
# econ_r_macd_signal_252
# econ_r_macd_hist_252
# econ_r_resid_forecast_252
# econ_r_beta_d504
# econ_r_resid_std_d504
# econ_r_resid_z_d504
# econ_r_resid_total_deviation_per_price_d504
# econ_r_resid_adf_p_d504
# econ_r_z_times_1_minus_p_value_504
# econ_r_resid_std_times_z_times_1_minus_p_value_504
# econ_r_res_mom_12_1_504
# econ_r_res_rev_5d_504
# econ_r_res_rsi_14_504
# econ_r_res_streak_504
# econ_r_macd_line_504
# econ_r_macd_signal_504
# econ_r_macd_hist_504
# econ_r_resid_forecast_504
# Ticker

# %%
original_features_built.columns
# Out:
# Index(['Date', 'Stock_price', 'ETF_price', 'SP500_price', 'Stock_return',
#        'Sector_return', 'Econ_return', 'vr_5d', 'vr_20d', 'vr_60d', 'vr_120d',
#        'sector_tracking_error_d1', 'econ_tracking_error_d1',
#        'sector_p_beta_d126', 'sector_p_resid_std_d126',
#        'sector_p_resid_z_d126',
#        'sector_p_resid_total_deviation_per_price_d126',
#        'sector_p_resid_adf_p_d126', 'sector_p_z_times_1_minus_p_value_126',
#        'sector_p_resid_std_times_z_times_1_minus_p_value_126',
#        'sector_p_res_mom_06_1_126', 'sector_p_res_rev_5d_126',
#        'sector_p_res_rsi_14_126', 'sector_p_res_streak_126',
#        'sector_p_macd_line_126', 'sector_p_macd_signal_126',
#        'sector_p_macd_hist_126'],
#       dtype='str')

# %%
print('Existing mean reversion features are', temp.columns), print('Sample of old mean reversion feature',original_features_built.columns)
# Out:
# Existing mean reversion features are Index(['index', 'Date', 'Stock_price', 'ETF_price', 'SP500_price',
#        'Stock_return', 'Sector_return', 'Econ_return', 'vr_5d', 'vr_20d',
#        ...
#        'econ_r_resid_std_times_z_times_1_minus_p_value_504',
#        'econ_r_res_mom_12_1_504', 'econ_r_res_rev_5d_504',
#        'econ_r_res_rsi_14_504', 'econ_r_res_streak_504',
#        'econ_r_macd_line_504', 'econ_r_macd_signal_504',
#        'econ_r_macd_hist_504', 'econ_r_resid_forecast_504', 'Ticker'],
#       dtype='str', length=195)
# Sample of old mean reversion feature Index(['Date', 'Stock_price', 'ETF_price', 'SP500_price', 'Stock_return',
#        'Sector_return', 'Econ_return', 'vr_5d', 'vr_20d', 'vr_60d', 'vr_120d',
#        'sector_tracking_error_d1', 'econ_tracking_error_d1',
#        'sector_p_beta_d126', 'sector_p_resid_std_d126',
#        'sector_p_resid_z_d126',
#        'sector_p_resid_total_deviation_per_price_d126',
#        'sector_p_resid_adf_p_d126', 'sector_p_z_times_1_minus_p_value_126',
#        'sector_p_resid_std_times_z_times_1_minus_p_value_126',
#        'sector_p_res_mom_06_1_126', 'sector_p_res_rev_5d_126',
#        'sector_p_res_rsi_14_126', 'sector_p_res_streak_126',
#        'sector_p_macd_line_126', 'sector_p_macd_signal_126',
#        'sector_p_macd_hist_126'],
#       dtype='str')
# (None, None)

# %%
print('Common features are:', common_features)
if original_features_built.columns.isin(temp.columns).all():
    print('new mean reversion features include all sample features')
else:
    print('Misisng features:', missing_features)
# Out:
# Common features are: Index(['Date', 'Stock_price', 'ETF_price', 'SP500_price', 'Stock_return',
#        'Sector_return', 'Econ_return', 'vr_5d', 'vr_20d', 'vr_60d', 'vr_120d',
#        'sector_tracking_error_d1', 'econ_tracking_error_d1',
#        'sector_p_beta_d126', 'sector_p_resid_std_d126',
#        'sector_p_resid_z_d126',
#        'sector_p_resid_total_deviation_per_price_d126',
#        'sector_p_resid_adf_p_d126', 'sector_p_z_times_1_minus_p_value_126',
#        'sector_p_resid_std_times_z_times_1_minus_p_value_126',
#        'sector_p_res_mom_06_1_126', 'sector_p_res_rev_5d_126',
#        'sector_p_res_rsi_14_126', 'sector_p_res_streak_126',
#        'sector_p_macd_line_126', 'sector_p_macd_signal_126',
#        'sector_p_macd_hist_126'],
#       dtype='str')
# new mean reversion features include all sample features

# %%
price_data.to_csv('Experimental_data.csv')

# %%
temp
# Out:
#       index       Date  Stock_price   ETF_price  SP500_price  Stock_return  \
# 0         0 2020-01-02    51.171631   92.306099  3257.850098           NaN
# 1         1 2020-01-03    51.179028   91.501709  3234.850098      0.000145
# 2         2 2020-01-06    50.994053   92.071106  3246.280029     -0.003621
# 3         3 2020-01-07    50.483517   91.890350  3237.179932     -0.010062
# 4         4 2020-01-08    50.979252   92.486847  3253.050049      0.009772
# ...     ...        ...          ...         ...          ...           ...
# 1591   1591 2026-05-04   106.639999  144.729996  7200.750000     -0.007846
# 1592   1592 2026-05-05   105.160004  145.300003  7259.220215     -0.013976
# 1593   1593 2026-05-06   105.010002  145.399994  7365.120117     -0.001427
# 1594   1594 2026-05-07   107.150002  144.720001  7337.109863      0.020174
# 1595   1595 2026-05-08   106.099998  143.490005  7398.930176     -0.009848
#
#       Sector_return  Econ_return     vr_5d    vr_20d  ...  \
# 0               NaN          NaN       NaN       NaN  ...
# 1         -0.008753    -0.007085       NaN       NaN  ...
# 2          0.006204     0.003527       NaN       NaN  ...
# 3         -0.001965    -0.002807       NaN       NaN  ...
# 4          0.006470     0.004890       NaN       NaN  ...
# ...             ...          ...       ...       ...  ...
# 1591      -0.002967    -0.004070  0.179190  0.117033  ...
# 1592       0.003931     0.008087  0.135538  0.098195  ...
# 1593       0.000688     0.014483  0.117657  0.112642  ...
# 1594      -0.004688    -0.003810  0.054270  0.125344  ...
# 1595      -0.008535     0.008390  1.095323  0.138919  ...
#
#       econ_r_resid_std_times_z_times_1_minus_p_value_504  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1591                                          -0.006089
# 1592                                          -0.018077
# 1593                                          -0.008570
# 1594                                           0.021877
# 1595                                          -0.014038
#
#       econ_r_res_mom_12_1_504  econ_r_res_rev_5d_504  econ_r_res_rsi_14_504  \
# 0                         NaN                    NaN                    NaN
# 1                         NaN                    NaN                    NaN
# 2                         NaN                    NaN                    NaN
# 3                         NaN                    NaN                    NaN
# 4                         NaN                    NaN                    NaN
# ...                       ...                    ...                    ...
# 1591                -0.296359              -0.052708              51.190585
# 1592                -0.225604              -0.024749              49.982039
# 1593                -0.242793              -0.007091              48.594482
# 1594                -0.233141              -0.059806              52.672844
# 1595                -0.209638               0.024897              48.264359
#
#       econ_r_res_streak_504  econ_r_macd_line_504  econ_r_macd_signal_504  \
# 0                       NaN                   NaN                     NaN
# 1                       NaN                   NaN                     NaN
# 2                       NaN                   NaN                     NaN
# 3                       NaN                   NaN                     NaN
# 4                       NaN                   NaN                     NaN
# ...                     ...                   ...                     ...
# 1591                    0.0              0.002730                0.000228
# 1592                    0.0              0.000776                0.000338
# 1593                    0.0             -0.000005                0.000269
# 1594                    1.0              0.001812                0.000578
# 1595                    0.0              0.000349                0.000532
#
#       econ_r_macd_hist_504  econ_r_resid_forecast_504  Ticker
# 0                      NaN                        NaN     EHC
# 1                      NaN                        NaN     EHC
# 2                      NaN                        NaN     EHC
# 3                      NaN                        NaN     EHC
# 4                      NaN                        NaN     EHC
# ...                    ...                        ...     ...
# 1591              0.002502                  -0.000021     EHC
# 1592              0.000439                  -0.000009     EHC
# 1593             -0.000274                   0.000008     EHC
# 1594              0.001234                  -0.000005     EHC
# 1595             -0.000183                   0.000019     EHC
#
# [1596 rows x 195 columns]

# %%
from sklearn.metrics import r2_score

bad_features = []

for feature in common_features:
    common_indices = temp[feature].dropna().index.intersection(original_features_built[feature].dropna().index)
    print(feature)
    print((temp.loc[common_indices, feature] == original_features_built.loc[common_indices, feature]).all(),
          (temp.loc[common_indices, feature]== original_features_built.loc[common_indices, feature]).sum(),
          temp[feature].dropna().shape[0])
    data_similarity = r2_score( original_features_built.loc[common_indices, feature], temp.loc[common_indices, feature])
    print(data_similarity )
    # print(temp.loc[common_indices, feature].head(), original_features_built.loc[common_indices, feature].head())
    if data_similarity < 0.995:
        bad_features.append(feature)
    print('------------------')
# Out:
# Date
# True 1596 1596
# 1.0
# ------------------
# Stock_price
# True 1596 1596
# 1.0
# ------------------
# ETF_price
# True 1596 1596
# 1.0
# ------------------
# SP500_price
# True 1596 1596
# 1.0
# ------------------
# Stock_return
# True 1595 1595
# 1.0
# ------------------
# Sector_return
# True 1595 1595
# 1.0
# ------------------
# Econ_return
# True 1595 1595
# 1.0
# ------------------
# vr_5d
# True 1587 1587
# 1.0
# ------------------
# vr_20d
# True 1557 1557
# 1.0
# ------------------
# vr_60d
# True 1477 1477
# 1.0
# ------------------
# vr_120d
# True 1357 1357
# 1.0
# ------------------
# sector_tracking_error_d1
# True 1092 1092
# 1.0
# ------------------
# econ_tracking_error_d1
# True 1092 1092
# 1.0
# ------------------
# sector_p_beta_d126
# False 28 1470
# 0.9999999999994819
# ------------------
# sector_p_resid_std_d126
# False 28 1470
# 0.9999999999992815
# ------------------
# sector_p_resid_z_d126
# False 28 1470
# 0.9999999999893745
# ------------------
# sector_p_resid_total_deviation_per_price_d126
# False 28 1470
# 0.9999999999928733
# ------------------
# sector_p_resid_adf_p_d126
# False 28 1470
# 0.9999999999793918
# ------------------
# sector_p_z_times_1_minus_p_value_126
# False 28 1470
# 0.9999999999760215
# ------------------
# sector_p_resid_std_times_z_times_1_minus_p_value_126
# False 28 1470
# 0.9999999999807243
# ------------------
# sector_p_res_mom_06_1_126
# False 0 1345
# 0.999999999999845
# ------------------
# sector_p_res_rev_5d_126
# False 24 1466
# 0.9999999999983734
# ------------------
# sector_p_res_rsi_14_126
# False 14 1456
# 0.9999999999836608
# ------------------
# sector_p_res_streak_126
# False 633 1470
# 0.9999999999873133
# ------------------
# sector_p_macd_line_126
# False 1 1470
# 0.9999999999964929
# ------------------
# sector_p_macd_signal_126
# False 1 1470
# 0.9999999999977779
# ------------------
# sector_p_macd_hist_126
# False 1 1470
# 0.9999999999902052
# ------------------

# %%
if len(bad_features) == 0:
    print('No bad features')
else:
    print('Bad features are:')
    for feature in bad_features:
        print(feature)
        temp_series = temp[feature].dropna()
        or_series = original_features_built[feature].dropna()
        
        # print(temp_series)
        # print(or_series)
    
        print('----------------------------')
# Out:
#
# [1596 rows x 1710 columns]

# %%
import numpy as np
from functools import reduce

# -------- 1) Build regime features once --------
# regime_data has a 'Date' column + multiple regime columns (rates, gold, etc.)
reg = regime_data.copy()

reg["Date"] = pd.to_datetime(reg["Date"])
price_data_dates = price_data.index

start = price_data_dates.min()
end = price_data_dates.max()

reg = reg[(reg["Date"] >= start) & (reg["Date"] <= end)].copy()
reg = reg.sort_values("Date").ffill()

reg['Date'] = pd.to_datetime(reg['Date'])
reg = reg.sort_values('Date').set_index('Date')

reg_feats_parts = []
reg_last_parts  = []

for col in reg.columns:  # every regime series
    f, last = build_features(reg[col].astype(float))
    # drop the regime 'y' (your target is stock return, not regime-return)
    f = f.drop(columns=['y']).add_prefix(f"reg_{col}__").reset_index().rename(columns={'index': 'Date'})
    last = last.add_prefix(f"reg_{col}__").reset_index().rename(columns={'index': 'Date'})
    reg_feats_parts.append(f)
    reg_last_parts.append(last)

# Merge all regime feature blocks on Date
def _merge_on_date(a, b): 
    return a.merge(b, on='Date', how='outer')

regime_feats = reduce(_merge_on_date, reg_feats_parts) if reg_feats_parts else pd.DataFrame(columns=['Date'])
regime_last  = reduce(_merge_on_date, reg_last_parts)  if reg_last_parts  else pd.DataFrame(columns=['Date'])
# regime_feats = pd.concat([regime_feats, regime_last])
# print(regime_feats.shape)
# Out:
# C:\Users\zhan5\miniconda3\envs\jupyter_env\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\zhan5\miniconda3\envs\jupyter_env\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
from joblib import Parallel, delayed
import numpy as np
import pandas as pd

def build_base_features_for_one_ticker(ticker, price_data, mapping, sector_to_etf):

    price_column  = f'{ticker}_Close'
    volume_column = f'{ticker}_Volume'

    # --- Price features ---
    feats_p, last_p = build_features(price_data[price_column].astype(float))
    feats_p = feats_p.reset_index().rename(columns={'index': 'Date'})
    last_p  = last_p.reset_index().rename(columns={'index': 'Date'})

    # --- Volume features ---
    feats_v, last_v = build_features(price_data[volume_column].astype(float))
    feats_v = feats_v.drop(columns=['y']).add_prefix('vol_').reset_index().rename(columns={'index': 'Date'})
    last_v  = last_v.add_prefix('vol_').reset_index().rename(columns={'index': 'Date'})

    # --- Merge stock price + volume features ---
    feats_i = feats_p.merge(feats_v, on='Date', how='left')
    feats_i['Ticker'] = ticker
    last_i = last_p.merge(last_v, on='Date', how='left')
    last_i['Ticker'] = ticker

    # --- Sector ETF features ---
    sector = mapping.loc[mapping['Ticker'] == ticker, 'Sector']
    sector = sector.iloc[0] if not sector.empty else np.nan
    etf_ticker = sector_to_etf.get(sector, "SPY")

    etf_price_col = f"{etf_ticker}_Close"
    etf_vol_col   = f"{etf_ticker}_Volume"

    if etf_price_col in price_data.columns and etf_vol_col in price_data.columns:
        etf_p, etf_last_p = build_features(price_data[etf_price_col].astype(float))
        etf_p = etf_p.drop(columns=['y']).add_prefix("etf_").reset_index().rename(columns={"index": "Date"})
        etf_last_p = etf_last_p.add_prefix("etf_").reset_index().rename(columns={"index": "Date"})

        etf_v, etf_last_v = build_features(price_data[etf_vol_col].astype(float))
        etf_v = etf_v.drop(columns=['y']).add_prefix("etf_vol_").reset_index().rename(columns={"index": "Date"})
        etf_last_v = etf_last_v.add_prefix("etf_vol_").reset_index().rename(columns={"index": "Date"})

        feats_i = feats_i.merge(etf_p, on="Date", how="left").merge(etf_v, on="Date", how="left")
        last_i  = last_i.merge(etf_last_p, on="Date", how="left").merge(etf_last_v, on="Date", how="left")


    # --- Mean reversion features ---

    return feats_i, last_i
    
mmm_df = build_base_features_for_one_ticker('LW', price_data, mapping, sector_to_etf)
# mmm_df

# %%
all_basic_features = []

for ticker in selected_tickers:
    base_features = build_base_features_for_one_ticker(ticker, price_data, mapping, sector_to_etf)
    all_basic_features.append(base_features)

# %%
base_features_train = pd.concat([features[0] for features in all_basic_features])
base_features_deploy = pd.concat([features[1] for features in all_basic_features])

# %%
# base_features_train.merge(momentum_df)
# momentum_df


base_features_train  = add_sector(base_features_train, mapping)
base_features_deploy  = add_sector(base_features_deploy, mapping)
momentum_df  = add_sector(momentum_df, mapping)
global_mean_reversion_df   = add_sector(global_mean_reversion_df , mapping)

# %%
momentum_df = create_compressed_forecast_features(momentum_df )

# %%
momentum_df
# Out:
#            Date  lag_1_hold_21_forecast_return  lag_1_hold_21_p_value  \
# 0    2020-01-02                            NaN                    NaN
# 1    2020-01-03                            NaN                    NaN
# 2    2020-01-06                            NaN                    NaN
# 3    2020-01-07                            NaN                    NaN
# 4    2020-01-08                      -0.009810               0.028083
# ...         ...                            ...                    ...
# 4774 2026-04-29                       0.000467               0.014602
# 4775 2026-04-30                      -0.001416               0.014602
# 4776 2026-05-01                       0.000467               0.014602
# 4777 2026-05-04                       0.000252               0.014602
# 4778 2026-05-05                       0.000171               0.014602
#
#       lag_1_hold_21_corr_coef  lag_1_hold_21_ret_lag  \
# 0                         NaN                    NaN
# 1                         NaN               0.000145
# 2                         NaN              -0.003614
# 3                         NaN              -0.010011
# 4                   -0.999027               0.009820
# ...                       ...                    ...
# 4774                -0.061604              -0.007588
# 4775                -0.061604               0.022993
# 4776                -0.061604              -0.007580
# 4777                -0.061604              -0.004084
# 4778                -0.061604              -0.002769
#
#       forecast_s_times_1_minus_pval_1 Ticker  lag_5_hold_21_forecast_return  \
# 0                                 NaN    EHC                            NaN
# 1                                 NaN    EHC                            NaN
# 2                                 NaN    EHC                            NaN
# 3                                 NaN    EHC                            NaN
# 4                           -0.009535    EHC                            NaN
# ...                               ...    ...                            ...
# 4774                         0.000461    ATO                      -0.002141
# 4775                        -0.001396    ATO                      -0.001402
# 4776                         0.000460    ATO                      -0.002022
# 4777                         0.000248    ATO                      -0.001405
# 4778                         0.000168    ATO                      -0.000078
#
#       lag_5_hold_21_p_value  lag_5_hold_21_corr_coef  ...  \
# 0                       NaN                      NaN  ...
# 1                       NaN                      NaN  ...
# 2                       NaN                      NaN  ...
# 3                       NaN                      NaN  ...
# 4                       NaN                      NaN  ...
# ...                     ...                      ...  ...
# 4774               0.031615                -0.121324  ...
# 4775               0.031615                -0.121324  ...
# 4776               0.031615                -0.121324  ...
# 4777               0.031615                -0.121324  ...
# 4778               0.031615                -0.121324  ...
#
#       Sector_Financial Services*average_forecasted_returns_of_momentums  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                  -0.0
# ...                                                 ...
# 4774                                               -0.0
# 4775                                               -0.0
# 4776                                               -0.0
# 4777                                               -0.0
# 4778                                               -0.0
#
#       Sector_Financial Services*short_forecasted_returns_of_momentums  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4774                                               -0.0
# 4775                                               -0.0
# 4776                                               -0.0
# 4777                                               -0.0
# 4778                                               -0.0
#
#       Sector_Financial Services*long_forecasted_returns_of_momentums  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4774                                               -0.0
# 4775                                               -0.0
# 4776                                               -0.0
# 4777                                               -0.0
# 4778                                               -0.0
#
#       Sector_Healthcare*average_forecasted_returns_of_momentums  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                              -0.00981
# ...                                                 ...
# 4774                                           -0.00000
# 4775                                           -0.00000
# 4776                                           -0.00000
# 4777                                           -0.00000
# 4778                                           -0.00000
#
#       Sector_Healthcare*short_forecasted_returns_of_momentums  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4774                                               -0.0
# 4775                                               -0.0
# 4776                                               -0.0
# 4777                                               -0.0
# 4778                                               -0.0
#
#       Sector_Healthcare*long_forecasted_returns_of_momentums  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4774                                               -0.0
# 4775                                               -0.0
# 4776                                               -0.0
# 4777                                               -0.0
# 4778                                               -0.0
#
#       Sector_Utilities*average_forecasted_returns_of_momentums  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                             -0.000000
# ...                                                 ...
# 4774                                          -0.006821
# 4775                                          -0.008849
# 4776                                          -0.006919
# 4777                                          -0.006353
# 4778                                          -0.005970
#
#       Sector_Utilities*short_forecasted_returns_of_momentums  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4774                                          -0.003196
# 4775                                          -0.004427
# 4776                                          -0.003916
# 4777                                          -0.003523
# 4778                                          -0.003271
#
#       Sector_Utilities*long_forecasted_returns_of_momentums      Sector
# 0                                                   NaN      Healthcare
# 1                                                   NaN      Healthcare
# 2                                                   NaN      Healthcare
# 3                                                   NaN      Healthcare
# 4                                                   NaN      Healthcare
# ...                                                 ...             ...
# 4774                                          -0.017716       Utilities
# 4775                                          -0.021408       Utilities
# 4776                                          -0.016616       Utilities
# 4777                                          -0.015314       Utilities
# 4778                                          -0.014441       Utilities
#
# [4779 rows x 51 columns]

# %%
ranking_df = create_ranking_df(price_data)

# %%
def append_features(data_to_append_on:pd.DataFrame,
              features:pd.DataFrame,
                   join_features = ['Ticker', 'Date']):
    if features.columns.isin(data_to_append_on).all():
        return data_to_append_on
    else:
        existing_columns = [i for i in features.columns if i in data_to_append_on.columns and i not in ['Ticker', 'Date']]
        data_to_append_on = data_to_append_on.drop(existing_columns, axis = 1)
    df = data_to_append_on.merge(features, on = join_features, how = 'left')
    return df

print(base_features_train.shape)
base_features_train = append_features(base_features_train ,
              momentum_df)
base_features_deploy = append_features(base_features_deploy ,
              momentum_df)

print(base_features_train.shape)
base_features_train = append_features(base_features_train ,
              global_mean_reversion_df )
base_features_deploy = append_features(base_features_deploy ,
              global_mean_reversion_df )

print(base_features_train.shape)
base_features_train = append_features(base_features_train ,
              ranking_df )
base_features_deploy = append_features(base_features_deploy ,
              ranking_df )
print(base_features_train.shape)
# Out:
# (4779, 133)
# (4779, 180)
# (4779, 372)
# (4779, 375)

# %%
base_features_train = append_features(base_features_train ,
              regime_feats, join_features = ['Date'] )
base_features_deploy = append_features(base_features_deploy ,
              regime_last, join_features = ['Date'] )

# %%
base_features_train.dropna(axis = 1, how = 'all', inplace = True) 
print(base_features_train .shape)
base_features_deploy.dropna(axis = 0, how = 'all', inplace = True) 
print(base_features_deploy.shape)
# Out:
# (4779, 566)
# (3, 598)

# %%
    
rolling_1m_dollar_volume_df = create_rolling_1m_volume_data(price_data)
base_features_train = append_volume_data(base_features_train, rolling_1m_dollar_volume_df)
base_features_deploy = append_volume_data(base_features_deploy, rolling_1m_dollar_volume_df)

# %%
base_features_train['forecast_s_times_1_minus_pval_25*1_month_dollar_volume'] = base_features_train['rolling_1m_dollar_volume']*base_features_train['forecast_s_times_1_minus_pval_25']
base_features_train['forecast_s_times_1_minus_pval_60*1_month_dollar_volume'] = base_features_train['rolling_1m_dollar_volume']*base_features_train['forecast_s_times_1_minus_pval_60']
base_features_train['forecast_s_times_1_minus_pval_120*1_month_dollar_volume'] = base_features_train['rolling_1m_dollar_volume']*base_features_train['forecast_s_times_1_minus_pval_120']
base_features_train['forecast_s_times_1_minus_pval_250*1_month_dollar_volume'] = base_features_train['rolling_1m_dollar_volume']*base_features_train['forecast_s_times_1_minus_pval_250']

base_features_deploy['forecast_s_times_1_minus_pval_25*1_month_dollar_volume'] =base_features_deploy ['rolling_1m_dollar_volume']*base_features_deploy ['forecast_s_times_1_minus_pval_25']
base_features_deploy ['forecast_s_times_1_minus_pval_60*1_month_dollar_volume'] = base_features_deploy ['rolling_1m_dollar_volume']*base_features_deploy ['forecast_s_times_1_minus_pval_60']
base_features_deploy ['forecast_s_times_1_minus_pval_120*1_month_dollar_volume'] = base_features_deploy ['rolling_1m_dollar_volume']*base_features_deploy ['forecast_s_times_1_minus_pval_120']
base_features_deploy ['forecast_s_times_1_minus_pval_250*1_month_dollar_volume'] = base_features_deploy ['rolling_1m_dollar_volume']*base_features_deploy ['forecast_s_times_1_minus_pval_250']

# %%
base_features_train.to_csv('C:/Users/zhan5/OneDrive/Desktop/Quant/new_pipeline_train.csv')
base_features_deploy.to_csv('C:/Users/zhan5/OneDrive/Desktop/Quant/new_pipeline_deploy.csv')

# %%
from MetaLearner.StockSelection import SelectionConfig, run_rolling_backtest_selection, identify_stocks_for_deployment
from MetaLearner.Backtest import run_30_backtests, summarize_backtest_metrics, plot_equity_curves

# Unified training frame for stock-selection modeling
# (data_process_script already built 99% of this: we now run model/backtest/selection)
temp_feat_df = base_features_train.copy()
temp_feat_df['Date'] = pd.to_datetime(temp_feat_df['Date'])

selection_cfg = SelectionConfig(
    horizon_bd=21,
    model_type='elastic_net',
    train_data_density='soft',
    k_top=8,
    corr_thresh=0.9,
    nan_corr='reject',
    exclude_tickers=('sp500',),
)

# %%
# Canonical final aliases (ensures downstream cells use Backtest orchestration)
# Keep this as the cell to run after data processing is complete.
from MetaLearner.Backtest import run_selection_backtest

results_df = run_selection_backtest(
    df_all=temp_feat_df,
    price_df=price_data,
    config=selection_cfg,
    spacing_days=11,
    lookback_windows=8,
)
results_df['Num_stock'] = results_df['Returns'].apply(lambda x: len(x) if isinstance(x, list) else 0)

# Keep old variable name compatibility too
results_df_v2 = results_df.copy()
results_df[['TEST_DATE', 'Selected tickers (rows mode)', 'TopK mean realized return', 'Avg_predicted_return', 'Num_stock']].head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 5
#       1 # Canonical final aliases (ensures downstream cells use Backtest orchestration)
#       2 # Keep this as the cell to run after data processing is complete.
#       3 from MetaLearner.Backtest import run_selection_backtest
# ----> 5 results_df = run_selection_backtest(
#       6     df_all=temp_feat_df,
#       7     price_df=price_data,
#       8     config=selection_cfg,
#       9     spacing_days=11,
#      10     lookback_windows=8,
#      11 )
#      12 results_df['Num_stock'] = results_df['Returns'].apply(lambda x: len(x) if isinstance(x, list) else 0)
#      14 # Keep old variable name compatibility too
#
# File ~\OneDrive\Desktop\Quant\MetaLearner\Backtest\portfolio_backtest.py:123, in run_selection_backtest(df_all, price_df, config, spacing_days, lookback_windows, test_dates, newest_first, single_day_runner)
#     121 rows = []
#     122 for dt in eval_dates:
# --> 123     rows.append(single_day_runner(frame, price, dt, config=config))
#     124 return pd.DataFrame(rows)
#
# File ~\OneDrive\Desktop\Quant\MetaLearner\StockSelection\selection_engine.py:158, in run_experiment_single_day(df_all, price_df, test_date, config)
#     156 imputer = SimpleImputer(strategy="mean")
#     157 scaler = StandardScaler()
# --> 158 x_train = pd.DataFrame(imputer.fit_transform(x_train), columns=x_train.columns, index=x_train.index)
#     159 x_test = pd.DataFrame(imputer.transform(x_test), columns=x_test.columns, index=x_test.index)
#     160 x_train = pd.DataFrame(scaler.fit_transform(x_train), columns=x_train.columns, index=x_train.index)
#
# File ~\miniconda3\envs\jupyter_env\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File ~\miniconda3\envs\jupyter_env\Lib\site-packages\sklearn\base.py:907, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     892         warnings.warn(
#     893             (
#     894                 f"This object ({self.__class__.__name__}) has a `transform`"
#    (...)    902             UserWarning,
#     903         )
#     905 if y is None:
#     906     # fit method of arity 1 (unsupervised transformation)
# --> 907     return self.fit(X, **fit_params).transform(X)
#     908 else:
#     909     # fit method of arity 2 (supervised transformation)
#     910     return self.fit(X, y, **fit_params).transform(X)
#
# File ~\miniconda3\envs\jupyter_env\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File ~\miniconda3\envs\jupyter_env\Lib\site-packages\sklearn\impute\_base.py:447, in SimpleImputer.fit(self, X, y)
#     429 @_fit_context(prefer_skip_nested_validation=True)
#     430 def fit(self, X, y=None):
#     431     """Fit the imputer on `X`.
#     432
#     433     Parameters
#    (...)    445         Fitted estimator.
#     446     """
# --> 447     X = self._validate_input(X, in_fit=True)
#     449     # default fill_value is 0 for numerical input and "missing_value"
#     450     # otherwise
#     451     if self.fill_value is None:
#
# File ~\miniconda3\envs\jupyter_env\Lib\site-packages\sklearn\impute\_base.py:374, in SimpleImputer._validate_input(self, X, in_fit)
#     372         raise new_ve from None
#     373     else:
# --> 374         raise ve
#     376 if in_fit:
#     377     # Use the dtype seen in `fit` for non-`fit` conversion
#     378     self._fit_dtype = X.dtype
#
# File ~\miniconda3\envs\jupyter_env\Lib\site-packages\sklearn\impute\_base.py:355, in SimpleImputer._validate_input(self, X, in_fit)
#     352     ensure_all_finite = True
#     354 try:
# --> 355     X = validate_data(
#     356         self,
#     357         X,
#     358         reset=in_fit,
#     359         accept_sparse="csc",
#     360         dtype=dtype,
#     361         force_writeable=True if not in_fit else None,
#     362         ensure_all_finite=ensure_all_finite,
#     363         copy=self.copy,
#     364     )
#     365 except ValueError as ve:
#     366     if "could not convert" in str(ve):
#
# File ~\miniconda3\envs\jupyter_env\Lib\site-packages\sklearn\utils\validation.py:2902, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2900         out = X, y
#    2901 elif not no_val_X and no_val_y:
# -> 2902     out = check_array(X, input_name="X", **check_params)
#    2903 elif no_val_X and not no_val_y:
#    2904     out = _check_y(y, **check_params)
#
# File ~\miniconda3\envs\jupyter_env\Lib\site-packages\sklearn\utils\validation.py:1074, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1068     raise ValueError(
#    1069         f"Found array with dim {array.ndim},"
#    1070         f" while dim <= 2 is required{context}."
#    1071     )
#    1073 if ensure_all_finite:
# -> 1074     _assert_all_finite(
#    1075         array,
#    1076         input_name=input_name,
#    1077         estimator_name=estimator_name,
#    1078         allow_nan=ensure_all_finite == "allow-nan",
#    1079     )
#    1081 if copy:
#    1082     if _is_numpy_namespace(xp):
#    1083         # only make a copy if `array` and `array_orig` may share memory`
#
# File ~\miniconda3\envs\jupyter_env\Lib\site-packages\sklearn\utils\validation.py:133, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     130 if first_pass_isfinite:
#     131     return
# --> 133 _assert_all_finite_element_wise(
#     134     X,
#     135     xp=xp,
#     136     allow_nan=allow_nan,
#     137     msg_dtype=msg_dtype,
#     138     estimator_name=estimator_name,
#     139     input_name=input_name,
#     140 )
#
# File ~\miniconda3\envs\jupyter_env\Lib\site-packages\sklearn\utils\validation.py:182, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     165 if estimator_name and input_name == "X" and has_nan_error:
#     166     # Improve the error message on how to handle missing values in
#     167     # scikit-learn.
#     168     msg_err += (
#     169         f"\n{estimator_name} does not accept missing values"
#     170         " encoded as NaN natively. For supervised learning, you might want"
#    (...)    180         "#estimators-that-handle-nan-values"
#     181     )
# --> 182 raise ValueError(msg_err)
#
# ValueError: Input X contains infinity or a value too large for dtype('float64').

# %%
import matplotlib.pyplot as plt

# Quick strategy diagnostics
viz_df = results_df.copy()
viz_df['TEST_DATE'] = pd.to_datetime(viz_df['TEST_DATE'])

plt.figure(figsize=(12, 4))
plt.plot(viz_df['TEST_DATE'], viz_df['TopK mean realized return'], label='TopK realized return', marker='o', alpha=0.8)
plt.plot(viz_df['TEST_DATE'], viz_df['Avg_predicted_return'], label='TopK predicted return', marker='o', alpha=0.8)
plt.axhline(0, color='black', linestyle='--', linewidth=1)
plt.legend()
plt.grid(alpha=0.2)
plt.title('Predicted vs Realized Top-K Returns')
plt.tight_layout()

plt.figure(figsize=(6, 5))
plt.scatter(viz_df['Avg_predicted_return'], viz_df['TopK mean realized return'], alpha=0.8)
plt.xlabel('Average predicted return')
plt.ylabel('TopK mean realized return')
plt.title('Signal Quality Check')
plt.grid(alpha=0.2)
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 4
#       1 import matplotlib.pyplot as plt
#       3 # Quick strategy diagnostics
# ----> 4 viz_df = results_df.copy()
#       5 viz_df['TEST_DATE'] = pd.to_datetime(viz_df['TEST_DATE'])
#       7 plt.figure(figsize=(12, 4))
#
# NameError: name 'results_df' is not defined

# %%
# Portfolio-level backtest on selected tickers
bt_source = results_df[(results_df['Avg_predicted_return'] > 0.0) & (results_df['Num_stock'] >= 3)].copy()

metrics_df, equities = run_30_backtests(price_data, bt_source, hold_days=21)
summary = summarize_backtest_metrics(metrics_df)
print(summary)
metrics_df

# %%
bt_source
# Out:
#      TEST_DATE     Selected tickers (rows mode)  \
# 4   2026-02-27             [LW, CHRW, EHC, DHI]
# 5   2026-02-11             [LW, CHRW, THG, ATO]
# 6   2026-01-27             [LW, CHRW, EHC, THG]
# 9   2025-12-08       [DHI, THG, FAST, CHRW, LW]
# 10  2025-11-20  [CHRW, FAST, LW, ATO, THG, DHI]
# 11  2025-11-05                  [CHRW, EHC, LW]
#
#                                               Returns  \
# 4   [-0.16279967322473543, -0.13118915761900343, -...
# 5   [-0.21427579382227688, -0.14417847608369733, 0...
# 6   [0.06020597207980857, 0.02002755802458556, 0.1...
# 9   [-0.043784028371080384, -0.002119530199861314,...
# 10  [0.10882261139517835, 0.06429896716538007, -0....
# 11  [0.03035285387928631, -0.02458420096644419, -0...
#
#                                     Predicted_returns  \
# 4   [0.08060874779226808, 0.04480882549189527, 0.0...
# 5   [0.0511087543651961, 0.029420498488855786, 0.0...
# 6   [0.07951085343260186, 0.07795169911887946, 0.0...
# 9   [0.04477933219569549, 0.01514394796006892, 0.0...
# 10  [0.09640644443524865, 0.06560574809912449, 0.0...
# 11  [0.0438099545964922, 0.01495927221096809, 0.00...
#
#     TopK mean realized return  Avg_predicted_return  Num_stock  HORIZON_BD  \
# 4                   -0.146438              0.045377          4        21.0
# 5                   -0.068403              0.024936          4        21.0
# 6                    0.064063              0.045454          4        21.0
# 9                   -0.061675              0.018586          5        21.0
# 10                  -0.005941              0.047498          6        21.0
# 11                  -0.014739              0.022794          3        21.0
#
#    Train end (exclusive)  Train samples  ...  Train R^2  Train RMSE  \
# 4             2026-01-29          511.0  ...   0.449604    0.067681
# 5             2026-01-13          511.0  ...   0.449604    0.067681
# 6             2025-12-29          504.0  ...   0.448754    0.067489
# 9             2025-11-07          497.0  ...   0.455334    0.066304
# 10            2025-10-22          490.0  ...   0.459385    0.066451
# 11            2025-10-07          483.0  ...   0.458450    0.066532
#
#     Train MAE  Train Directional Acc  Test R^2  Test RMSE  Test MAE  \
# 4    0.050181               0.701375 -3.975487   0.148507  0.117085
# 5    0.050181               0.701375 -1.071823   0.137107  0.109371
# 6    0.049793               0.689243 -3.778463   0.067484  0.060620
# 9    0.049253               0.696970 -0.277893   0.152074  0.098021
# 10   0.049383               0.709016 -0.313289   0.131183  0.078718
# 11   0.049458               0.708940 -0.760893   0.055087  0.042727
#
#     Test Directional Acc  Test Correlation  Picked rows count
# 4               0.285714         -0.705402                4.0
# 5               0.714286         -0.195194                4.0
# 6               0.857143         -0.426745                4.0
# 9               0.285714         -0.097697                5.0
# 10              0.571429          0.024740                6.0
# 11              0.428571         -0.250294                3.0
#
# [6 rows x 21 columns]

# %%
# Equity-curve visualization across rolling backtests
plot_equity_curves(equities, title='Cumulative Return for Each Backtest')

# %%
# Deployment stock selection from latest feature rows
# base_features_deploy already contains the latest scoring rows
deployment_results = identify_stocks_for_deployment(
    df_all=temp_feat_df,
    deploy_df=base_features_deploy,
    price_df=price_data,
    config=selection_cfg,
)

deployment_results
# Out:
# {'TEST_DATE': datetime.date(2026, 5, 1),
#  'Selected tickers (rows mode)': [],
#  'Top Predicted Returns': [],
#  'Avg_predicted_return': 0.0}

# %%
# Gap conclusion from notebook comparison (kept in notebook for traceability)
required_buildout = {
    'Backtest submodule': [
        'run_30_backtests',
        'summarize_backtest_metrics',
        'plot_equity_curves',
    ],
    'StockSelection submodule': [
        'SelectionConfig',
        'select_topk_rows_with_corr_filter',
        'run_experiment_single_day',
        'run_rolling_backtest_selection',
        'identify_stocks_for_deployment',
    ],
}
required_buildout
# Out:
# {'Backtest submodule': ['run_30_backtests',
#   'summarize_backtest_metrics',
#   'plot_equity_curves'],
#  'StockSelection submodule': ['SelectionConfig',
#   'select_topk_rows_with_corr_filter',
#   'run_experiment_single_day',
#   'run_rolling_backtest_selection',
#   'identify_stocks_for_deployment']}

# %%
# Comparison conclusion: what still had to be implemented in MetaLearner
# after data_process_script completed the 99% data-processing layer.
required_buildout = {
    'new_python_files': [
        'MetaLearner/StockSelection/selection_engine.py',
        'MetaLearner/StockSelection/__init__.py',
        'MetaLearner/Backtest/portfolio_backtest.py',
        'MetaLearner/Backtest/__init__.py',
        'MetaLearner/BackTest.py',
    ],
    'stock_selection_functions': [
        'SelectionConfig',
        'select_topk_rows_with_corr_filter',
        'run_experiment_single_day',
        'run_rolling_backtest_selection',
        'identify_stocks_for_deployment',
    ],
    'backtest_functions': [
        'run_30_backtests',
        'summarize_backtest_metrics',
        'plot_equity_curves',
    ],
    'notes': [
        'Backtest is the professional naming convention; BackTest alias is provided for compatibility.',
        'No existing notebook code was deleted; only additive buildout was performed.',
    ],
}
required_buildout
# Out:
# {'new_python_files': ['MetaLearner/StockSelection/selection_engine.py',
#   'MetaLearner/StockSelection/__init__.py',
#   'MetaLearner/Backtest/portfolio_backtest.py',
#   'MetaLearner/Backtest/__init__.py',
#   'MetaLearner/BackTest.py'],
#  'stock_selection_functions': ['SelectionConfig',
#   'select_topk_rows_with_corr_filter',
#   'run_experiment_single_day',
#   'run_rolling_backtest_selection',
#   'identify_stocks_for_deployment'],
#  'backtest_functions': ['run_30_backtests',
#   'summarize_backtest_metrics',
#   'plot_equity_curves'],
#  'notes': ['Backtest is the professional naming convention; BackTest alias is provided for compatibility.',
#   'No existing notebook code was deleted; only additive buildout was performed.']}
